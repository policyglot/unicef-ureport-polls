# %% [markdown]
# # UNICEF Youth Opinions Visualization
# ## Using PySpark and Leaflet.js to Map Global Diversity of Mindsets Among Millenials

# %% [markdown]
# This notebook consists of two sections. The first experiments with a tiny percentage (1%) of the full dataset to understand the required approaches to building visualizations. The second section then conducts similar analyses for the full dataset (1 GB>) in PySpark. Finally, results are visualized using Plotly and Leaflet.js

# %% [markdown]
# "All poll titles, question titles, order of questions are metadata generated by U-Report programme managers – not data coming directly from the system."
#
# "Org_language refers to the language on the website, not necessarily the language of the polls."
# We will therefore expect cases where the language of the polls does not match the stated one. But the initial assumption should be that they are indeed the same.

# %% [markdown]
# ### Identifying Notification Polls-
# # Needs Future Work
# "Poll_url is unique to every poll, total of 4,399 to date. A subset of these “polls” are notifications and only have a single “question” for which there are no set response"
#
# We would benefit from removing these notifications.

# %%
df[df['question_results_open_ended']]['data_segment_category'].unique()
# Out:
# array(['total', 'location', 'age'], dtype=object)

# %%
df[['data_type', 'question_title', 'data_category_label']]
# Out:
#        data_type                                     question_title  \
# 0       response               ¿Cuál es la red social que más usás?
# 1       response               ¿Cuál es la red social que más usás?
# 2      set_unset  ¿Cuánto tiempo por día pasas en la red social ...
# 3       response  ¿Cuánto tiempo por día pasas entre todas las r...
# 4       response  ¿Cuánto tiempo por día pasas entre todas las r...
# ...          ...                                                ...
# 44674   response  ทราบหรือไม่ว่าในอนุสัญญาว่าด้วยสิทธิเด็ก มีสาร...
# 44675  set_unset  ทราบหรือไม่ว่าในอนุสัญญาว่าด้วยสิทธิเด็ก มีสาร...
# 44676  set_unset  จากสิทธิพื้นฐานทั้ง 4 ด้าน คุณคิดว่าด้านใดสำคั...
# 44677  set_unset  จากสิทธิพื้นฐานทั้ง 4 ด้าน คุณคิดว่าด้านใดสำคั...
# 44678  set_unset  จากสิทธิพื้นฐานทั้ง 4 ด้าน คุณคิดว่าด้านใดสำคั...
#
#              data_category_label
# 0                        Twitter
# 1                        Twitter
# 2                            set
# 3      Entre 1 y 2 horas por día
# 4         Más de 4 horas por día
# ...                          ...
# 44674                     ไม่รู้
# 44675                        set
# 44676                      unset
# 44677                      unset
# 44678                        set
#
# [44679 rows x 3 columns]

# %% [markdown]
# data_type
# set_unset = whether respondents gave a suitable response for this question
# response = breakdown of valid response options
#
# data_segment_category
#
#     total = all respondents, whether they have submitted age/gender/location or not
#     age = for respondents that submitted age, in age-bands
#     gender = for respondents that submitted gender
#     location = most granular category for location, on most platforms this is region or district
#
# data_segment_label = disaggregated data labels for each category of data_segment_category.
#
# For example, this would be
#
# data_category_label = label of either set/unset (for that data type) or label for the response
#
#
# - This creates a problem, because set_unset becomes an issue
# data_category_count = number of respondents falling into the data_category_label

# %% [markdown]
# Thoughts on exploring the data-
# Is it possible to get a global aggregation of responses to the same set of questions? Does the same questions have the same ID? Is there some way of aggregating across them

# %%
#First,the usual imports
import numpy as np
import pandas as pd
import random
filename = '../all_poll_data.2020.05.29/all_poll_data.2020.05.29.csv'
unicef_seed = 2020
from tqdm import tqdm
tqdm.pandas()
import re
from nltk.corpus import stopwords
# Out:
# c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages\tqdm\std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
from time import time

# %%
# Approach 1: Sampling
# https://stackoverflow.com/questions/22258491/read-a-small-random-sample-from-a-big-csv-file-into-a-python-data-frame#22259008
random.seed(a=unicef_seed)

p = 0.01  # 1% of the lines
# keep the header, then take only 1% of lines
# if random from [0,1] interval is greater than 0.01 the row will be skipped
df = pd.read_csv(
         filename,
         header=0, 
         skiprows=lambda i: i>0 and random.random() > p)

# %%
df.to_csv('ureport_sample.csv')

# %%
df = pd.read_csv('ureport_sample.csv')

# %%
print(df.shape)
# Out:
# (44679, 27)

# %%
df[['question_id', 'question_title', 'question_results_open_ended',
       'question_order', 'data_type', 'data_segment_category',
       'data_segment_label', 'data_category_label']].head()
# Out:
#    question_id                                     question_title  \
# 0        12689               ¿Cuál es la red social que más usás?
# 1        12689               ¿Cuál es la red social que más usás?
# 2        12690  ¿Cuánto tiempo por día pasas en la red social ...
# 3        12691  ¿Cuánto tiempo por día pasas entre todas las r...
# 4        12691  ¿Cuánto tiempo por día pasas entre todas las r...
#
#    question_results_open_ended  question_order  data_type  \
# 0                        False               1   response
# 1                        False               1   response
# 2                        False               2  set_unset
# 3                        False               3   response
# 4                        False               3   response
#
#   data_segment_category data_segment_label        data_category_label
# 0              location         Entre Ríos                    Twitter
# 1              location            Córdoba                    Twitter
# 2              location            Mendoza                        set
# 3              location           Santa Fe  Entre 1 y 2 horas por día
# 4              location            Formosa     Más de 4 horas por día

# %% [markdown]
# So this means the final dataset will have 4,467,600 responses. Right now, our aim is to find strategies to make this work in a subsample. Then we can find Big Data methods for parallelization.

# %%
# Explore Dataset
df.columns
# Out:
# Index(['org_name', 'org_language', 'org_id', 'org_host', 'org_subdomain',
#        'org_domain', 'poll_id', 'poll_flow_uuid', 'poll_title', 'poll_org',
#        'poll_created_on', 'poll_date', 'poll_category_image_url',
#        'poll_category_name', 'poll_url', 'question_ruleset_uuid',
#        'question_title', 'question_id', 'question_results_open_ended',
#        'question_order', 'data_type', 'data_segment_category',
#        'data_segment_label', 'data_category_label', 'data_category_count',
#        'data_order'],
#       dtype='object')

# %%
df['data_order']
# Out:
# 0        6
# 1        6
# 2        0
# 3        2
# 4        4
# 5        0
# 6        2
# 7        0
# 8        2
# 9        0
# 10       5
# 11       5
# 12       4
# 13       2
# 14       6
# 15       0
# 16       3
# 17       0
# 18       3
# 19       2
# 20       2
# 21       0
# 22       0
# 23       4
# 24       3
# 25       0
# 26       4
# 27       1
# 28       2
# 29       0
#         ..
# 44649    6
# 44650    0
# 44651    4
# 44652    7
# 44653    0
# 44654    0
# 44655    1
# 44656    1
# 44657    0
# 44658    0
# 44659    1
# 44660    2
# 44661    0
# 44662    0
# 44663    0
# 44664    2
# 44665    2
# 44666    1
# 44667    0
# 44668    0
# 44669    2
# 44670    2
# 44671    0
# 44672    0
# 44673    0
# 44674    2
# 44675    0
# 44676    0
# 44677    0
# 44678    0
# Name: data_order, Length: 44679, dtype: int64

# %%
df['data_segment_category'].value_counts()
# Out:
# location    32380
# age          5914
# total        4363
# gender       2022
# Name: data_segment_category, dtype: int64

# %%
df['data_segment_label'].value_counts()
# Out:
# total                   4363
# 15-19                   1011
# 20-24                   1001
# 0-14                     991
# 31-34                    982
# 35+                      967
# 25-30                    962
# Female                   425
# Male                     420
# Homme                    168
# Femme                    137
# Ayeyarwady               120
# Yangon                   114
# Hombre                   112
# အမျိုးသား                110
# Kayah                    106
# Chin                     104
# Shan                     102
# Tanintharyi              101
# Rakhine                   98
# Magway                    97
# အမျိုးသမီး                97
# Sagaing                   96
# Mon                       95
# Mujer                     95
# Kachin                    92
# Bago                      90
# Чоловіки                  89
# Mandalay                  86
# Kayin                     85
#                         ...
# Област Шумен               1
# Ariana - أريانة            1
# الأنبار                    1
# Rumonge                    1
# Provincia Guanacaste       1
# Област Пазарджик           1
# Putrajaya                  1
# Tafilah                    1
# هەولێر                     1
# Nord-Ubangi                1
# Област Стара Загора        1
# Pulau Papan                1
# Provincia Limón            1
# بابل                       1
# North-West                 1
# Lobatse                    1
# Monastir - المنستير        1
# Provincia San José         1
# Pool                       1
# أنثى                       1
# Bolívar                    1
# South-East                 1
# Jarash                     1
# Enga                       1
# Provincia Cartago          1
# Chimbu                     1
# Jwaneng                    1
# Област Благоевград         1
# Vakaga                     1
# Област Русе                1
# Name: data_segment_label, Length: 1510, dtype: int64

# %% [markdown]
# It seems like most of the variety in this variable comes from the location tag. There are also some variants with the meaning of 'male' and 'female' in different languages. Those could easily be standardized into one.
#
# Location will be challenging to use. We could later use some geospatial libraries like geopy to visualize them.

# %%
df.groupby(['data_segment_category'])['data_segment_label'].value_counts()
# Out:
# data_segment_category  data_segment_label
# age                    15-19                   1011
#                        20-24                   1001
#                        0-14                     991
#                        31-34                    982
#                        35+                      967
#                        25-30                    962
# gender                 Female                   425
#                        Male                     420
#                        Homme                    168
#                        Femme                    137
#                        Hombre                   112
#                        အမျိုးသား                110
#                        အမျိုးသမီး                97
#                        Mujer                     95
#                        Чоловіки                  89
#                        Жінки                     75
#                        Perempuan                 40
#                        Laki-Laki                 35
#                        Masculino                 28
#                        Ragazzi                   26
#                        Rapaz                     25
#                        Feminino                  19
#                        Masculin                  18
#                        Erkak                     17
#                        Ragazze                   16
#                        Feminin                   15
#                        Meninas                   15
#                        Žensko                    14
#                        Muško                     13
#                        Ayol                       6
#                                                ...
# location               Enga                       1
#                        Jarash                     1
#                        Jwaneng                    1
#                        Lobatse                    1
#                        Monastir - المنستير        1
#                        Nord-Ubangi                1
#                        North-West                 1
#                        Orange Walk District       1
#                        Pool                       1
#                        Provincia Cartago          1
#                        Provincia Guanacaste       1
#                        Provincia Limón            1
#                        Provincia Puntarenas       1
#                        Provincia San José         1
#                        Pulau Papan                1
#                        Putrajaya                  1
#                        Rumonge                    1
#                        South-East                 1
#                        Tafilah                    1
#                        Thaba-Tseka District       1
#                        Vakaga                     1
#                        Област Благоевград         1
#                        Област Пазарджик           1
#                        Област Русе                1
#                        Област Стара Загора        1
#                        Област Шумен               1
#                        الأنبار                    1
#                        بابل                       1
#                        هەولێر                     1
# total                  total                   4363
# Name: data_segment_label, Length: 1510, dtype: int64

# %% [markdown]
# This exploration would be most valuable if we had some level of standardization. The age variable stays the same across countries, regardless of language. However, we will need a standardized set.

# %%
df['data_category_label'].value_counts()
# Out:
# unset                                   7213
# set                                     7084
# No                                      1878
# Yes                                     1468
# yes                                      292
# no                                       276
# unknown                                  246
# Non                                      200
# Da                                       199
# Oui                                      188
# Si                                       176
# C                                        139
# Nu                                       138
# Others                                   137
# Not sure                                 129
# B                                        126
# A                                        124
# D                                        106
# Other specify                            103
# Так                                      102
# Ні                                        99
# Sí                                        96
# Don't know                                82
# Інше                                      78
# E                                         76
# အျခား                                     72
# Sim                                       69
# Education                                 67
# None                                      66
# Lainnya                                   64
#                                         ...
# Fear of testing self                       1
# Journey to school                          1
# 1 séance                                   1
# problemi familiari                         1
# Je ne sens pas le besoin                   1
# Qiz bola uyda o'tirishi kerak              1
# Crăciunul pe stil vechi                    1
# Nafas qisishi                              1
# improve                                    1
# polio                                      1
# Xola-ammalar                               1
# minha                                      1
# No, I'm not surprised                      1
# Révision des cours                         1
# Moddiy yordam                              1
# В дитинстві займ. не за власним бажа       1
# UADB                                       1
# Memes, imágenes en Instagram etc.          1
# They don’t come to school while men        1
# Can't get a new bf / gf                    1
# Couva Tabaquite Talparo                    1
# add                                        1
# Children are vulnerable than adults        1
# 1 juta orang                               1
# holidays                                   1
# အထ                                         1
# Bor, lekin qiziqarli emas                  1
# 3 weeks or less                            1
# CSCOM                                      1
# เน้นให้ผู้เรียนได้ลงมือทำ                  1
# Name: data_category_label, Length: 12771, dtype: int64

# %% [markdown]
# These are the sets of answers to poll questions. We can no whether or not they are open-ended through the

# %% [markdown]
# There is no index or identifier for individual users. That becomes more problematic later, when we try to combine the columns for age, location and gender. We have multiple rows now for what could well have been the same individual.
#
# We also note that essentially, our dataset is a combination of three sets of information (three tables in database):
# - Organization
# - Poll
# - Question
#
# The complication emerges at the level of questions. We need to be sure that we can find the same questions being asked across the world so as to discern geographic patterns to youth responses

# %%
df[['org_id', 'poll_org']]
# Out:
#        org_id  poll_org
# 0           8         8
# 1           8         8
# 2           8         8
# 3           8         8
# 4           8         8
# ...       ...       ...
# 44674       5         5
# 44675       5         5
# 44676       5         5
# 44677       5         5
# 44678       5         5
#
# [44679 rows x 2 columns]

# %%
df['org_id'].equals(df['poll_org'])
# Out:
# True

# %% [markdown]
# The code above proves that 'org_id' is a primary key in the 'org' table and 'poll_org' is its foreign key in the Poll table.

# %%
for col in df.columns:
    print(df[col].unique())
# Out:
# ['Argentina' 'Bangladesh' 'Belize' 'Bolivia' 'Bosnia and Herzegovina'
#  'Botswana' 'Brasil' 'Bulgaria' 'Burkina Faso' 'Burundi' 'Cameroon'
#  'Chile' 'Congo Brazzavile' 'Congo(RDC)' 'Costa Rica' "Côte d'Ivoire"
#  'Ecuador' 'El Salvador' 'FSM' 'France' 'Gambia' 'Ghana' 'Guatemala'
#  'Guinea' 'Haiti' 'Honduras' 'India' 'Indonesia' 'Ireland' 'Jamaica'
#  'Jordan' 'Kiribati' 'Lesotho' 'Liberia' 'Malawi' 'Malaysia' 'Mexico'
#  'Moldova' 'Moçambique' 'Myanmar' 'Nigeria' 'On the Move' 'Pacific'
#  'Pakistan' 'Papua New Guinea' 'Philippines' 'România'
#  'République Centrafricaine' 'Senegal' 'Sierra Leone' 'South Africa'
#  'Srbija' 'Tanzania' 'Tchad' 'Trinidad and Tobago' 'Tunisie'
#  'U-Report Global' 'U-Report24x7' 'U-report Mali' 'Uganda' 'Uzbekistan'
#  'VIETNAM' 'Western Balkans' 'Zimbabwe' 'eSwatini' 'УКРАЇНА'
#  'العراق\u200e' 'ประเทศไทย']
# ['es' 'en' 'bs' 'pt-br' 'bg' 'fr' 'id' 'ar' 'ro' 'pt' 'my' nan 'it'
#  'sr-rs@latin' 'uz' 'vi' 'uk' 'th']
# [ 8 17 15 27 19 42  1 33 23  5 10 12 32 46 28 26 49  4 40 38  7 20 41 25
#  21  2 11 45 43  6 36 22  9 47 16 44 14 31 29 13 39  3 18 35]
# ['ilhasoft' 'nyaruka' 'ona']
# ['argentina' 'bangladesh' 'belize' 'bolivia' 'bih' 'botswana' 'brasil'
#  'bulgaria' 'burkinafaso' 'burundi' 'cameroon' 'chile' 'congobrazzaville'
#  'drc' 'costarica' 'cotedivoire' 'ecuador' 'elsalvador' 'fsm' 'france'
#  'gambia' 'ghana' 'guatemala' 'guinea' 'haiti' 'honduras' 'india'
#  'indonesia' 'ireland' 'jamaica' 'jordan' 'kiribati' 'les' 'liberia'
#  'malawi' 'malaysia' 'mexico' 'moldova' 'mozambique' 'myanmar' 'nigeria'
#  'onthemove' 'pacific' 'pakistan' 'png' 'philippines' 'romania'
#  'centrafrique' 'senegal' 'sierraleone' 'sa' 'serbia' 'tanzania' 'tchad'
#  'tt' 'tunisie' nan 'nigeria24x7' 'mali' 'uganda' 'uzbekistan' 'vietnam'
#  'westernbalkans' 'zimbabwe' 'eswatini' 'ukraine' 'iraq' 'thailand']
# [nan 'ureport.org.bd' 'ureportbrasil.org.br' 'ureport.mw' 'smsbiz.co.mz'
#  'ureport.pk' 'ureport.in' 'tanzania.ilhasoft.mobi' 'ureport.ug']
# [1734 1731 1729 ...  341  144  102]
# ['5a7577ea-aa1f-4f9c-b031-78ab91695448'
#  '25a68a75-a4b0-40e6-a3db-d1b221a0a8a1'
#  '46695ae4-f08b-4b9d-8f6c-9e96613b4e2f' ...
#  '4066cc1d-f8be-4bfe-86e5-7358903c6115'
#  '986cf4be-6cbf-4ab5-9865-5a6f905a66b6'
#  'a694c3e3-edc0-42d1-a429-602394d32180']
# ['¿Cuáles son las redes sociales preferidas por los adolescentes argentinos?'
#  '¿Cómo afecta el Aislamiento Preventivo Social y Obligatorio a los hogares con Discapacidad?'
#  '¿Cómo es la situación en el hogar de los adolescentes y jóvenes durante la Cuarentena?'
#  ...
#  'อนุสัญญาว่าด้วยสิทธิเด็กระบุว่า เด็ก ๆ มีสิทธิที่จะแสดงออกในสิ่งที่พวกเขาคิด และความเห็นของพวกเขาควรได้รับการพิจารณาตามสมควร\r\n\r\nเพื่อน ๆ คิดว่าตัวเองสามารถใช้สิทธิในการมีส่วนร่วมแสดงแสดงความเห็นได้ในระดับใด?'
#  'ไม่ทราบว่าเพื่อนๆ ของยูรีพอร์ตเตอร์มีประสบการณ์ถูกกลั่นแกล้งบนโลกออนไลน์หรือไม่ และทราบหรือไม่ว่าหากพบเห็นการกลั่นแกล้งบนโลกออนไลน์ควรทำอย่างไร?'
#  'ประเทศไทยได้ลงนามเข้าเป็นภาคีอนุสัญญาว่าด้วยสิทธิเด็กเมื่อวันที่ 12 กุมภาพันธ์ พ.ศ.2535 ทราบหรือไม่ว่าอนุสัญญานี้ มีหลักการสำคัญในการคุ้มครองสิทธิพื้นฐานของเด็กด้านใดบ้าง?']
# [ 8 17 15 27 19 42  1 33 23  5 10 12 32 46 28 26 49  4 40 38  7 20 41 25
#  21  2 11 45 43  6 36 22  9 47 16 44 14 31 29 13 39  3 18 35]
# ['2020-05-26T17:56:01.923397Z' '2020-05-21T17:34:35.251576Z'
#  '2020-05-20T21:19:33.292310Z' ... '2016-09-04T02:04:12.076488Z'
#  '2016-07-25T16:13:36.879219Z' '2016-07-20T07:10:01.478350Z']
# ['2020-06-01T16:15:12Z' '2020-05-26T21:41:03Z' '2020-06-20T20:01:04Z' ...
#  '2016-09-03T16:53:02Z' '2016-07-25T15:56:23.170Z' '2016-07-19T08:22:54Z']
# ['https://ureport-app.s3.amazonaws.com/categories/D75A7888.jpg' nan
#  'https://ureport-app.s3.amazonaws.com/categories/categoria-participacion.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/D75A7776.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/223_EncuentroEstudiantesSecundaria_SanPedroDeColalao_Unicef_Haar.JPG'
#  'https://ureport-app.s3.amazonaws.com/categories/UN071581.JPG'
#  'https://ureport-app.s3.amazonaws.com/categories/_Z7A5977_hmM4VcB.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/UN063143.JPG'
#  'https://ureport-app.s3.amazonaws.com/categories/About_UN036683.JPG'
#  'https://ureport-app.s3.amazonaws.com/categories/CHILDREN_DAY.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/protectothers-flu.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/Child_Marriage.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/end_violence_in_schools.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/Father_and_son_around_a_table.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/IMG_905000.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/youtubeHeader.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/tecnologia.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/embarazo-adolescente-2.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/52828226_1905274656266698_7244330194385764352_o.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/BTWA2010-00123.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/14046074_1100002170053644_7485649861087958499_n.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/2013.11.20_Placido_de_Castro_RT_L9615.JPG'
#  'https://ureport-app.s3.amazonaws.com/categories/Foto_04_Historia__UNICEF_BRZ_JO%C3%83O_RIPPER.jpeg'
#  'https://ureport-app.s3.amazonaws.com/categories/ODS2_1024.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/banner-site-ureport-fakenews_2.png'
#  'https://ureport-app.s3.amazonaws.com/categories/ODS1_1260.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/dark-facebook_1.png'
#  'https://ureport-app.s3.amazonaws.com/categories/WhatsApp_Image_2019-02-25_at_11.28.02.jpeg'
#  'https://ureport-app.s3.amazonaws.com/categories/Logo.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/partiumudar.png'
#  'https://ureport-app.s3.amazonaws.com/categories/banner-site-ureport-imigrantes.png'
#  'https://ureport-app.s3.amazonaws.com/categories/banner-site-ureport-Aprendizes.png'
#  'https://ureport-app.s3.amazonaws.com/categories/38728035_1364674510332368_7721250655788072960_n.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/abuso-face1.png'
#  'https://ureport-app.s3.amazonaws.com/categories/2013.11.29_Lagoa_Santa_RT_L0336.JPG'
#  'https://ureport-app.s3.amazonaws.com/categories/28576297_1234851409981346_1490539533782077526_n.png'
#  'https://ureport-app.s3.amazonaws.com/categories/ODS5_1024.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/quetirofoiesse.png'
#  'https://ureport-app.s3.amazonaws.com/categories/reducao.png'
#  'https://ureport-app.s3.amazonaws.com/categories/_MG_5234t.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/ODS14_1024.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/ODS9_1024.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/ODS3_1024.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/ODS1_1024.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/thumbnail_abordagem-post_1024.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/image006.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/homepageureport.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/16299238_972345992898557_6754522811543730131_n.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/15039682_1248409808538194_613966408641866961_o.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/letalidadeviolenta_628px.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/Oli2016.png'
#  'https://ureport-app.s3.amazonaws.com/categories/opnions.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG_7694.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG_8573.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG_8538.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/cybercriminalite.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG_8615.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG_8553.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/mariage_des_enfants_2.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG_0842.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG_8734.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG_6843.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG_8406.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/violence.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/lionnes_contre.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/malnutrition_poll.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Profil_site_draft.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/U_report.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/09_Sticker_A6_u-report.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/UN_cover_page.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Couverture_autres.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/4.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/cover_test.png'
#  'https://dl-ureport.s3.amazonaws.com/categories/13.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/gender_equality.jpeg'
#  'https://dl-ureport.s3.amazonaws.com/categories/sustentabilidad.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/_E4X0176.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/ureport_Brazza2.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/_UNICEF-UN0311514-Tremeau.png'
#  'https://dl-ureport.s3.amazonaws.com/categories/09_DR_Congo2018_Tremeau_1R6A3315.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/2017_05_MAYO_14_AMI_UNICEF_SKATE_PARK_0898.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Young_people.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/WeCanDoItChallenge.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Nutririon.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Live_Chat_3.png'
#  'https://dl-ureport.s3.amazonaws.com/categories/IvoryCoast0377.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/31643913475_1446674d44_o.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/UN0254174.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/CIV.HIV.Benjaminkro.31.07.2019.UNICEF.FrankDejongh.2150.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG_6193-min.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/un_day.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/UN032913_Med-Res.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/corruption.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/sport.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/MDIA8695.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/Internet.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/CIV16.0217.UNICEF_067.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/maman.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/Historia_1_-_Arcos.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/Proteccin_-_Arcos.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/Salud_-_Arcos.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/Educacin_-_Arcos.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/Participacin_-_Troppoli.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/33226018150_e309946be0_h.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/Manos.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/manos.png'
#  'https://ureport-app.s3.amazonaws.com/categories/DSC_4023.JPG'
#  'https://ureport-app.s3.amazonaws.com/categories/circulo_08.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/3Q0A6653_1.JPG'
#  'https://ureport-app.s3.amazonaws.com/categories/3Q0A5214_1OK.JPG'
#  'https://ureport-app.s3.amazonaws.com/categories/report_44.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/rubrique-ureport-sante-alimentation-unicef.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/rubrique-education-ureport-france.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/rubrique-ureport-france.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/rubrique-citoyennete-jeunes-ureport-france.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/rubrique-protection-ureport-france.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/rubrique-environnement-ureport-france.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/rubrique-engagement-solidarite-ureport-france.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/ureport-sport-football-rubrique.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/rubrique-inegalites-jeunes-ureport-france.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/radio_mouv.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/GAM-2018-Noorani-0551-Health.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/GAM-2018-Noorani-0270-Advocacy.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/GAM-2018-JJack-1749-SDGs.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/GAM-2018-Noorani-0463-ChildProtection.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/GAM-2018-JJack-2428-UReporters.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/0G3A5521.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/GAM-2018-Noorani-0089-Nutrition.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/GAM-2018-Noorani-0338.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Article_image.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/_DSC3370.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/News_Story.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/PL_BTS-54.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/UNICEF-GUAA2007-00212-Claudio_Versiani.JPG'
#  'https://ureport-app.s3.amazonaws.com/categories/2.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/Sheli_Marielos_Jonathan.png'
#  'https://ureport-app.s3.amazonaws.com/categories/WhatsApp_Image_2019-10-03_at_12.29.34_RKLcAbt.jpeg'
#  'https://ureport-app.s3.amazonaws.com/categories/IMG-20180624-WA0014.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/the_last_chance_2.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/UN066782.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Fabcebook-inforgraphie-guin.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Jeunes_U-Report_GN.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG_1028.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/Wash_U-Report.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/jeux_olympic_2016.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/20160330_112620.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Join_Page.png'
#  'https://ureport-app.s3.amazonaws.com/categories/5_2.a76ef047d8d24c03823acdf41c4ee7c8.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/UNICEF_Honduras_2015_Bach_095_.a76ef047d8d24c03823acdf41c4ee7c8.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/AK8I1500.JPG'
#  'https://ureport-app.s3.amazonaws.com/categories/India001.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/UN016431.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/India006.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/India007.png'
#  'https://dl-ureport.s3.amazonaws.com/categories/edit_General_category_banner_UNICEF_Indonesia_1_0306090628_Josh_Estey_1.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Innovation_Category_Banner_MG_1032.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/Option1_ADAP_Category_Banner_MG_1298.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/Child_Protection_Category_Banner_280711_PAPAU68_IMG_9873.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Social_Policy_Category_Banner_P1010391.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/Education_Category_Banner_IDSA2011-00025.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/HIV_Category_Banner_MG_0998.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/crop1_Option2_Immunization_Category_Banner_IMG_9797.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/3.png'
#  'https://ureport-app.s3.amazonaws.com/categories/13.png'
#  'https://ureport-app.s3.amazonaws.com/categories/8.png'
#  'https://ureport-app.s3.amazonaws.com/categories/SAM_2232.JPG'
#  'https://ureport-app.s3.amazonaws.com/categories/main.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/zeminar.jpeg'
#  'https://ureport-app.s3.amazonaws.com/categories/14.png'
#  'https://ureport-app.s3.amazonaws.com/categories/16.png'
#  'https://ureport-app.s3.amazonaws.com/categories/2.png'
#  'https://ureport-app.s3.amazonaws.com/categories/10.png'
#  'https://ureport-app.s3.amazonaws.com/categories/urpeorterspage.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/UN0271202.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/zikaunicef1-e1462890148747.jpeg'
#  'https://ureport-app.s3.amazonaws.com/categories/Screenshot_2019-02-01_at_11.51.27_AM.png'
#  'https://dl-ureport.s3.amazonaws.com/categories/Children_on_the_Move.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/U_Reporters_in_general.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/00223.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/UNI47385.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/polio2.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/00181.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/liberia-yassah-watta-nutrition.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/UNI47347.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/BULLYING.png'
#  'https://dl-ureport.s3.amazonaws.com/categories/UNI27763.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/1909241_10152835282054002_784070331518677868_o.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/10838108_567436266691539_213717288242520369_o.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/2U7A2864.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/Child_Marriage_-_Charlie_Hartono.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Nutrition_U-Report_Malawi_by_Charlie_Hartono.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Groupie.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/DSC_0014.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/P_20180529_121140.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Malawi_Charlie_Hartono.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG-20190311-WA0084.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/DSC_9823.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/upload.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/Water_Sanitation_and_Health_Charlie_Hartono.tif'
#  'https://dl-ureport.s3.amazonaws.com/categories/UN015619_Med-Res.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/p1_main_030418_p1_adn_1.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/youth_pic.3.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/unnamed.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/SISMO_Voluntarios.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/HidalgoUnicef_equesada_3982.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/_F2U0276.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/UNI35391.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/081920141016_UNICEFNuevoColoniaSantaCatarina-Edit.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/UN014979_Med-Res.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/pexels-photo-393034.jpeg'
#  'https://ureport-app.s3.amazonaws.com/categories/26001256_1958102791096372_2795990109045472451_n.png'
#  'https://ureport-app.s3.amazonaws.com/categories/GHIBZPY4FS.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/apple-device-casual-close-up-1430118.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/unicef-218_Childrens_Rights.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/Antreprenor.jpeg'
#  'https://ureport-app.s3.amazonaws.com/categories/shutterstock_371506588_Large_.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/michaeldale_3.png'
#  'https://dl-ureport.s3.amazonaws.com/categories/Acordo_Ensino_Tecnico_1.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/OuroNegro_pamphlet.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Mae_de_bebe_colera_vacinacao.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Vacinacao_Polio.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG_20190423_131501_2.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Cidades_Sustentaveis_Amigas_da_Crianca.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/2015.07-Casamento-Prematuro-e-Gravidez-na-Adolescencia-em-Mocambique.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/polio_vaccine_campaing_28.01.PNG'
#  'https://dl-ureport.s3.amazonaws.com/categories/mensagens-para-o-dia-de-sao-valentim-kXbeN-fxl.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/servicos_de_saude.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/2017.10.24-World-Childrens-Day-small-1200x675-c-default.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/intxunaveis.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/nih-turned-down-investigators-who-provoked-ire-from-alcohol-industry-m.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/conferencia_Global_sobre_cuidados_primarios_de_saude_2018.PNG'
#  'https://dl-ureport.s3.amazonaws.com/categories/image.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Somos_todos_iguais_criancas_com_albinismo.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/crian%C3%A7a.png'
#  'https://dl-ureport.s3.amazonaws.com/categories/dia-internacional-da-mulher-1.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/hiv_sida.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMAG1904.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Young_people_texting.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Primeira-Menstrua%C3%A7%C3%A3o-Marrom1.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/2016.05.01-Anita-Budget-Briefs-SPPIM-672x372.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/20130527-avanza-en-la-legislatura-proyecto-contra-violencia-de-gnero.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/AMEBI.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Desenho-para-o-Folha-Educativa-Janeiro.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Nutrition_MOZA2012-00385.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/WASH_MOZA2013-00281.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/_DSC5455.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/KKW_2688.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/fifteen_percent.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG_4138.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/Health_5.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/GET_TESTED_1.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/COMPLEMENTARY_FEEDING.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Sanitation_1.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/SDG.png'
#  'https://dl-ureport.s3.amazonaws.com/categories/Ureport_3.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Golden_2.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/ChildProtection_1.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/cd978b6632653be515fc16b9099b411c.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Family_planning.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Education_2.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Aquila_OVP.png'
#  'https://dl-ureport.s3.amazonaws.com/categories/stop_voilence.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/NEW_POLIO_CASE_CARTOON.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/20171031_163134.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/regstn2.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/16767822830_27f6c26b5c_b.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/j7.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/20171031_174157.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/child_safe.jpeg'
#  'https://dl-ureport.s3.amazonaws.com/categories/edc.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/tr.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/LAVORO-IN-NERO.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG-20170503-WA0003_1.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/pALERMO.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/PAK-2010-Noorani-0401.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG_9405.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/PAK-2010-Noorani-0034.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/PAK-2010-Noorani-1778.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/PAK-2010-Noorani-0194.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/2D3A7024.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/2D3A7078.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/2D3A7117.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/2D3A7020.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG_E0476.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/Banderole_Introduction_VPI.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/UNI142244.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Depistage_CISJEU_Bangui.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/MINUSCA4.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/UNI176999.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Lavage-mains21-copy.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Inondation.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/UNI137357.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/HEALTH_Pudolski_Senegal_2009_20174.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/PROTECTION_Pirozzi_2008.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/EDUCATION_Pirozzi_2008.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/UREPORT_Pirozzi_2008.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/ADVOCACY_Pirozzi_2008.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG_0112.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/HIV_Pirozzi_2008.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/SLE13.0917.UNCF0319.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/19924848738_b20b0150e3_o.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/21386854128_dc8d7e0a49_o.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/12088302_1151484931532943_3182527651042210899_n.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/clouds_940.png'
#  'https://dl-ureport.s3.amazonaws.com/categories/AnnJohansson0109.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/Handwashing-Day.png'
#  'https://dl-ureport.s3.amazonaws.com/categories/WAD2015_socialimage_06.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/19381890691_9a214f9cf6_b.jpg'
#  'https://production-ureport-ona-io.s3.amazonaws.com/categories/girls-playing-soccer.jpg'
#  'https://production-ureport-ona-io.s3.amazonaws.com/categories/Health.jpg'
#  'https://production-ureport-ona-io.s3.amazonaws.com/categories/Youth-Participation.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/girl_looking_at_phone_girl_portrait_outdoor_scenery_portrait_young_phone_fema_r2MjOMs.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/marvin-meyer-571072-unsplash.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/anna-samoylova-535880-unsplash.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/stefan-vladimirov-1299266-unsplash.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/christopher-burns-360244-unsplash.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/hiv_1.jpeg'
#  'https://ureport-app.s3.amazonaws.com/categories/first_story.jpeg'
#  'https://ureport-app.s3.amazonaws.com/categories/Screen_Shot_2019-08-20_at_09.28.13.png'
#  'https://ureport-app.s3.amazonaws.com/categories/Temeke_Primary_School_July_9_2014_-_Brandon_Hill_33.jpeg'
#  'https://ureport-app.s3.amazonaws.com/categories/32222520_1974744422855437_1395243791375400960_o.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/srh.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/breastfeeding_7.jpeg'
#  'https://ureport-app.s3.amazonaws.com/categories/iwd.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/finance.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/P26B4481.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Coelo_2Z3A9556-EDUCATION-COMMUNICATION.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/Enfants_Migrants.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/UN015793resized.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/download.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/cameroun-nigeria-592x296.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/MHD.png'
#  'https://dl-ureport.s3.amazonaws.com/categories/Coelo_2Z3A9643-PROTECTION.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/AgriTchad.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/ChangementClimatique.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/UNICEF_Chad-ESteve_3.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/TUN-2018-Noorani-0759.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/TUN-2017-Noorani-0328.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/CK4A4230.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/Story.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/14264038_1388686597811500_3162633175998761257_n.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Picture_violence.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/UN069059.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/hand-644145_1920.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/_MG_4469.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/_UNICEF-UNI163964-Holt_Tanzania_2.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/HLM3_Asia.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/U-Report_Global_Cover_Photo_1.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/UNI181400.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/FB_ad_DO_ZA_HN.png'
#  'https://dl-ureport.s3.amazonaws.com/categories/UNI182891_UNICEFNYHQ2015-0857Hamoud.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Violence_against_women.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/website4.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Scouts.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/Phone_Girl.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/RUTF.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Primary_Colour_RGB.png'
#  'https://dl-ureport.s3.amazonaws.com/categories/borehole.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/1794706_1505323019722558_8729010315276662188_n.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Clinic_doctor.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/DpVvttrW0AIsZdL_1.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Education_1.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Bannieres_Twitter_01_HD.png'
#  'https://dl-ureport.s3.amazonaws.com/categories/Health_005.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/mine_3.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Nutrition_2.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Education_002.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG_9398.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG-20190415-WA0005.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG_9382.JPG'
#  'https://ureport-app.s3.amazonaws.com/categories/%D1%88%D0%BA%D0%BE%D0%BB%D0%BB%D1%8C_2.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/%D0%BD%D0%B0%D1%81.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/%D0%92%D0%B8%D1%87_%D0%BD%D0%B5.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/%D1%81%D1%82.png'
#  'https://ureport-app.s3.amazonaws.com/categories/%D0%A1%D1%82%D0%B0%D1%80%D1%82%D0%B0%D0%BF%D1%8B.png'
#  'https://ureport-app.s3.amazonaws.com/categories/%D0%A1%D0%BE%D1%86%D0%B0%D0%BA%D1%82.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/%D0%BA%D0%B0%D0%BD%D0%B8%D0%BA4.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/%D0%A1%D1%82%D1%80%D0%B0%D1%82%D0%B5%D0%B3%D0%B8%D1%8F_2019.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/C55A4827.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/lam-cach-nao-de-bao-ve-tre-em-tren-moi-truong-mang.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/UN020386_Med-Res.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/UPSHIFT-Incubation-8.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/MKRS_poll_image.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/New_Year_Resolution.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/main_about.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Child_Protection_001.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/DSC_0824.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/Health_001.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/Social_Policy_--1.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Education_001.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG_3787.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/water_carrying.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/General_1.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/endviolence.png'
#  'https://dl-ureport.s3.amazonaws.com/categories/nercha.5.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/hiv-test_2.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Screen_Shot_2016-08-18_at_12.56.38.png'
#  'https://dl-ureport.s3.amazonaws.com/categories/breastfeed.jpeg'
#  'https://dl-ureport.s3.amazonaws.com/categories/dac.JPG'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG_0102.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/26778_hd.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/bigstock-Modern-Keyboard-With-Colored-S-68403502.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/1422036607frwrn.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/IMG_8855-Edit.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/debaty.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/bullying.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Ukraine_Icon_1.png'
#  'https://dl-ureport.s3.amazonaws.com/categories/tumblr_ny7h5kaj961slhhf0o1_1280.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/16505949.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/68104243-happy-new-year-wallpapers.jpg'
#  'https://dl-ureport.s3.amazonaws.com/categories/Teener1.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/UN0263760.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/RD8A7699.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/F1-02.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/UNI74743.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/UN0209590.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/UNI118536.JPG'
#  'https://ureport-app.s3.amazonaws.com/categories/UNI27979.JPG'
#  'https://ureport-app.s3.amazonaws.com/categories/Green_Logo_Background.png'
#  'https://ureport-app.s3.amazonaws.com/categories/WCD_photo5.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/UN0119399.jpg'
#  'https://ureport-app.s3.amazonaws.com/categories/%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%99%E0%B8%B3%E0%B9%80%E0%B8%AA%E0%B8%99%E0%B8%AD1.jpg']
# ['Comunicación' 'Inclusión' 'Protección' 'Participación Adolescente'
#  'Educación' 'Salud' 'Fechas Importantes' 'Igualdad de Género'
#  'Cambio Climático' 'COVID-19' 'HIV/AIDS' 'WASH' 'Nutrition'
#  'Child Protection' 'Gender' 'Featured Poll' 'Mental Health' 'ECM'
#  'Health' 'Youth Engagement' 'General' 'Education' 'Overview TAG'
#  'Internal Migration' 'World Cities Day' 'Children Participation'
#  'End Violence' 'Social Protection' 'Adolescencia' 'Participación' 'Niñez'
#  'embarazo' 'Ureporteri' 'Adolescents & HIV' 'U-Report Brasil' 'Saúde'
#  'Educação' 'ODS 2 - Fome Zero' '+Q'
#  'Objetivos do Desenvolvimento Sustentável' 'ODS' 'Mete a colher'
#  'ODS Geral' 'HIV ' 'Política' 'Migrantes' 'Aprendiz' 'Esportes'
#  'Violência Sexual' 'Evasão Escolar' 'Corpo e Gordofobia'
#  'ODS 5 - Igualdade de Gênero' 'Corpo' 'Redução' 'Juv e Trabalho'
#  'Direitos Reprodutivos e Prevenções' 'Proteção'
#  "ODS 14 - Vida debaixo D'Água"
#  'ODS 9 - Indústria, Inovação e Infraestrutura'
#  'ODS 3 - Saúde e Bem-Estar' 'ODS 1 - Erradicação da Pobreza'
#  'Abordagem Policial' 'Acesso à justiça' 'ARMAS' 'DROGAS' 'Rede LGBT'
#  'Letalidade Violenta' 'Segurança' 'S4D' 'Opinions' 'Participation'
#  'Santé' 'Cybercrime' 'Hygiène' "Droits de l'enfant" 'Général'
#  'Eau, Assainissement et Hygiène' "Protection de l'enfant" 'Environnement'
#  'Helpline' 'Sustentabilidad' 'Contingencia' 'Politique Social' 'Jeunesse'
#  'Jeunessse  / Adolescence' 'Enfance' 'U-Report' 'Opiniones'
#  'Participation des jeunes' 'Protection ' 'Eau et hygiène' 'VIH/Sida'
#  "Droits de l'Homme" 'Emploi' 'Média' 'Diplomatie' 'Consommation'
#  'Politique' 'Sports' 'Économie et finances' 'Innovations'
#  'Santé reproductive sexuelle' 'Culture' 'Emergencia' 'Emergencias'
#  'Políticas Sociales' 'Zika' 'Internet'
#  'Adolescent and Youth Participation' 'Éducation' 'Citoyenneté'
#  'Protection' 'Engagement/solidarité' 'Sport' 'Inégalités' "Radio Mouv'"
#  'Advocacy' 'SDGs' 'Immunization' 'Migration' 'U-Reporters'
#  'Health and Nutrition' 'Current Issues' 'Adolescents and Young People'
#  'Social Policy' 'Agua y sanimiento' 'Salud Adolescente' 'Protección '
#  'U-Report Guatemala' 'Participación adolescente' 'Uso de tiempo libre'
#  'Cambio Climático 2' 'Primera Infancia' 'Matrimonio infantil'
#  'Embarazo adolescente' 'Objetivos de Desarrollo Sostenible (ODS)'
#  'SANTÉ ' 'GOUVERNANCE' 'POLITIQUES SOCIALES (Social inclusion)'
#  'EDUCATION' 'Wash' 'SPORT' 'VIH/ SIDA' "PROTECTION DE L'ENFANT"
#  'Communcation Externe' 'Droits des enfants' 'Niñez y adolescencia'
#  'Join & Engage' 'Redes sociales' 'Políticas'
#  'Child Development & Nutrition' 'Disaster Risk Reduction'
#  'Reproductive  & Child Health' 'Innovation' 'ADAP' 'General Topics'
#  'Health & Well-Being Goal 3' 'Climate Action Goal 13'
#  'Work & Economy Goal 8' 'Partnerships Goal 17'
#  'Sustainable Development Goals' 'Education Goal 4'
#  'Life Below Water Goal 14' 'Refugees & Migration'
#  'Peace & Justice Goal 16' 'Zero Hunger Goal 2'
#  'Reduce Inequalities Goal 10' 'Gender Equality Goal 5'
#  'Safety & security' 'Online' 'Development' 'Children on the Move'
#  'Adolescents and Youth' 'Climate/Environment' 'Bullying' 'Ebola'
#  'COVID-19 Response' 'Sexual and Gender Based Violence' 'Emergency'
#  'Food and Nutrition' 'World Aids Day' 'Water, Sanitation and Hygiene'
#  'Environment' 'Derechos' 'Tecnología' 'Alte sondaje'
#  'Sănătate și bunăstare' 'Media și tehnologie' 'Educație și viața școlară'
#  'Drepturile copiilor & monitorizare' 'Carieră'
#  'Monitorizarea drepturilor' 'Obiectivele de Dezvoltare Durabilă'
#  'Participare si dezvoltare' 'Protecția copilului' 'Mediu înconjurător'
#  'CORONAVIRUS 2019 - (COVID-19)' 'EMPREGO' 'Ouro Negro'
#  'Inquérito de Satisfação sobre Serviços de SSR - 09 Dec 2019'
#  'Child Protection - Bilhete de Identidade' 'Ciclone IDAI e Cheias'
#  'Campanha de Vacinacao do Polio' 'Social Mobilizers_WASH Interventions'
#  'CIDADES AMIGAS DAS CRIANCAS' 'Saúde Materna Infantil'
#  'Pré-Campanha sobre a Pólio - 28 a 29 de Janeiro 2018'
#  'São Valentim - Dia dos Namorados'
#  'Inquérito de Satisfação sobre Serviços de SSR - SOFH 15.12.18'
#  'World Children Day 20th November 2018' 'Radionovela os Intxunáveis'
#  'Prevencao do consumo de alcool, tabaco e drogas  ilegais.'
#  'Inquérito Global sobre os Cuidados de Saúde Primários'
#  'Violencia nas escolas' 'Dia Internacional do Albinismo'
#  'DIA MUNDIAL DA CRIANÇA' 'DIA INTERNACIONAL DA MULHER'
#  'HIV, TRANSMISSÃO, PREVENÇÃO, TRATAMENTO' 'ADESÃO AS UNIDADES SANITÁRIAS'
#  'SMS BIZ - COMO USAR' 'Higiene Menstrual - 28 Maio'
#  'SAÚDE SEXUAL E REPRODUTIVA' 'EDUCAÇÃO' 'Violência contra as Raparigas'
#  'Casamentos Prematuros' 'Violência contra Menores' 'Comunicação'
#  'MALARIA' 'RELACIONAMENTOS' 'SEXUALIDADE' 'Climate Change' 'Governance'
#  'Youth & Digital' 'Youth' 'Disaster' 'Infrastructure' 'Child protection'
#  'Peace and Social Cohesion' 'Employment' 'Youth policy'
#  'U-reporters General' 'Outbreaks' 'Water and Sanitation' 'Advocacy 4'
#  'Ureport & Policy Makers ' 'GIRL CHILD ' 'Innovation ' "Partner's poll"
#  'OVP polls' 'Global poll' 'Polio comms' 'FMoH/NPHCDA' 'COVID19' 'Diritti'
#  'Emergenza' 'Coinvolgimento giovani' 'Hate speech' 'Aspirazioni' 'Scuola'
#  'Accesso ai servizi' 'Tolleranza' 'Orientamento Professionale'
#  'Sistema di accoglienza' 'Informazioni legali' 'Attività ricreative'
#  'Ambiente' 'Adolescent and Youth' 'Water, Sanitation and Hygiene '
#  'Social Cohesion' 'BARMM Adolescent and Youth Issues' 'Sondaje' 'Paix'
#  'Santé- Wash' 'Santé et Nutrition' 'U-Report Senegal'
#  'Plaidoyer et Participation' 'VIH/SIDA' 'Emploi et Entrepreneuriat '
#  'Community Engagements' 'Disaster & Emmergencies'
#  'Child Protection & Education' 'Sanitation' 'Arts & Culture' 'HIV / AIDS'
#  'Youth Participation' 'Zaštita životne sredine' 'Obrazovanje' 'Ankete'
#  'Bezbednost' 'Obrada podataka' 'Prioriteti mladih' 'Ishrana'
#  'Zapošljavanje' 'Informisanje' 'Ravnopravnost' 'Prevencija nasilja'
#  'Seaweed' 'Engagement' 'Livelihood' 'Communication' 'Sante' 'Hygiene'
#  'Entreprenariat' 'Changement Climatique' 'Polio'
#  'U-Report in Emergencies' 'Youth Voices' 'Health and Wellness'
#  'Safety in Schools' 'Racism' 'Drugs and Crime' 'Volontariat en Tunisie'
#  "Lutte contre l'abandon scolaire" 'Journée mondiale des enfants'
#  "Journée mondiale des enfants (World Children's Day)"
#  "Violence à l'égard des enfants et adolescents" 'Citoyenneté mondiale'
#  'Transport scolaire' 'Sujets U-Report' 'Girls' 'Facebook'
#  'UNICEF Stories' 'join & engage' 'Emergencies'
#  'Girl Guides & Girl Scouts' 'Youth Group' 'Scouts' 'UNGA'
#  'U-Report24x7 General' 'Protection, Conflict, Emergency' 'FGM'
#  'Child Health' 'Disabilities' 'Ante-natal care' 'Quality of education'
#  'Early Childhood Development' 'Livelihoods' 'Media' 'Pregnancy'
#  'Child Marriage' "Ta'lim / Образование" 'Jamiyat / Общество'
#  "Sog'liqni saqlash / Здравоохранение" 'Ish / Работа'
#  'Innovatsiya / Инновация' 'Yoshlar / Молодежь' "Bo'sh vaqt / Досуг"
#  'Ijtimoiy masalalar / Социальные вопросы' 'Cyber Bullying'
#  'Bạo lực công cộng' 'Bạo lực gia đình' 'School bullying'
#  'U-Report Albania - Local Polls' 'Kosovo Local Polls'
#  'Montenegro Local Polls' 'U-Report Western Balkans'
#  'Climate and Environment' 'U-Report Global' 'HIV' 'Youth Parliament'
#  'Breastfeeding' 'DAC' 'Освіта' 'SDGs - Цілі сталого розвитку' 'LifeStyle'
#  "Здоров'я" 'Загальні' 'Саморозвиток' '#EndViolence - Протидія насильству'
#  'Урбаністика' 'U-Report у світі' 'Мистецтво' 'Гендерна рівність'
#  'New Year' 'ВІЛ/СНІД' 'Corona Virus Response' 'Child Rights' 'Well Being'
#  'Poll' 'Violence Against Children' 'เสียงเยาวชน' 'การคุ้มครองเด็ก'
#  'การศึกษา' 'อื่นๆ' 'นโยบายสังคม และ งานรณรงค์' 'เอชไอวี/เอดส์'
#  'Other images' 'สุขภาพ' 'สิทธิเด็ก' 'สถานการณ์ฉุกเฉิน' 'ความเหลื่อมล้ำ']
# ['https://argentina.ureport.in/poll/1734'
#  'https://argentina.ureport.in/poll/1731'
#  'https://argentina.ureport.in/poll/1729' ...
#  'https://thailand.ureport.in/poll/102'
#  'https://thailand.ureport.in/poll/62'
#  'https://thailand.ureport.in/poll/59']
# ['2b5014c7-06a4-488e-b6eb-382265c43891'
#  'd633271b-29d8-4e31-9833-c901ad0a0bae'
#  '438afa19-ecd0-4a0d-af80-18c6cf66a0af' ...
#  '17c71259-d9fe-420e-b578-083718431ee1'
#  '592ad9e5-12d3-4293-b057-4403d8f933bb'
#  '3a466063-2eae-455f-a322-f24d21662ef5']
# ['¿Cuál es la red social que más usás?'
#  '¿Cuánto tiempo por día pasas en la red social que más usas?'
#  '¿Cuánto tiempo por día pasas entre todas las redes sociales que usás?'
#  ...
#  'ไม่ทราบว่าเพื่อนๆ ของคุณเคยมีประสบการณ์ถูกกลั่นแกล้งบนโลกออนไลน์หรือไม่? (ตอบ เคย/ไม่เคย)'
#  'ทราบหรือไม่ว่าในอนุสัญญาว่าด้วยสิทธิเด็ก มีสาระสำคัญในการมุ่งคุ้มครองสิทธิเด็กอยู่กี่ด้าน อะไรบ้าง?'
#  'จากสิทธิพื้นฐานทั้ง 4 ด้าน คุณคิดว่าด้านใดสำคัญที่สุด?']
# [12689 12690 12691 ...   297   298   289]
# [False  True]
# [ 1  2  3  5  4  6  9 10 11 13 14 15 16 19 20 21 22 23 24 25 26 27  7  8
#  12 17 18 29 30]
# ['response' 'set_unset']
# ['location' 'age' 'total' 'gender']
# ['Entre Ríos' 'Córdoba' 'Mendoza' ... 'เลย' 'ร้อยเอ็ด' 'ลำพูน']
# ['Twitter' 'set' 'Entre 1 y 2 horas por día' ...
#  'ผู้ใหญ่ริเริ่มแต่เด็กมีส่วนร่วมตัดสิ' 'เด็กริเริ่มกำหนด' 'รู้']
# [0.000e+00 1.000e+00 2.400e+01 ... 1.301e+03 1.073e+03 4.737e+03]
# [  6   0   2   4   5   3   1   7  10  27  34  68  56  46  64  67  96  54
#   23  42  48  29  41   9  91  95  66  77  61  28  74   8  70  51  88  11
#   90  13  45  22  32  39  80  26  38  78  98  52  14  63  19  30  62  50
#   16  65  99  12  31  40  20  76  60  79  17 100  81  53  15  72  84  59
#   87  33  86  25  73  97  44  47  82  21  93  85  37  71  89  43  24  83
#   92  94  49  36  58  69  18  35  57  75  55]

# %%
df[['question_title','data_type', 'data_segment_category',
       'data_segment_label', 'data_category_label', 'data_category_count',
       'data_order']]
# Out:
#                                           question_title  data_type  \
# 0                   ¿Cuál es la red social que más usás?   response
# 1                   ¿Cuál es la red social que más usás?   response
# 2      ¿Cuánto tiempo por día pasas en la red social ...  set_unset
# 3      ¿Cuánto tiempo por día pasas entre todas las r...   response
# 4      ¿Cuánto tiempo por día pasas entre todas las r...   response
# ...                                                  ...        ...
# 44674  ทราบหรือไม่ว่าในอนุสัญญาว่าด้วยสิทธิเด็ก มีสาร...   response
# 44675  ทราบหรือไม่ว่าในอนุสัญญาว่าด้วยสิทธิเด็ก มีสาร...  set_unset
# 44676  จากสิทธิพื้นฐานทั้ง 4 ด้าน คุณคิดว่าด้านใดสำคั...  set_unset
# 44677  จากสิทธิพื้นฐานทั้ง 4 ด้าน คุณคิดว่าด้านใดสำคั...  set_unset
# 44678  จากสิทธิพื้นฐานทั้ง 4 ด้าน คุณคิดว่าด้านใดสำคั...  set_unset
#
#       data_segment_category data_segment_label        data_category_label  \
# 0                  location         Entre Ríos                    Twitter
# 1                  location            Córdoba                    Twitter
# 2                  location            Mendoza                        set
# 3                  location           Santa Fe  Entre 1 y 2 horas por día
# 4                  location            Formosa     Más de 4 horas por día
# ...                     ...                ...                        ...
# 44674              location              ชุมพร                     ไม่รู้
# 44675              location              พังงา                        set
# 44676              location          บุรีรัมย์                      unset
# 44677              location             สกลนคร                      unset
# 44678              location          อุตรดิตถ์                        set
#
#        data_category_count  data_order
# 0                      0.0           6
# 1                      0.0           6
# 2                      0.0           0
# 3                      0.0           2
# 4                      0.0           4
# ...                    ...         ...
# 44674                  0.0           2
# 44675                  0.0           0
# 44676                  0.0           0
# 44677                  0.0           0
# 44678                  0.0           0
#
# [44679 rows x 7 columns]

# %%
assert(len(df['poll_org'].unique())  == len(df['org_id'].unique()))

# %% [markdown]
# We could translate questions and check for similarities across languages. But this would not be the most economical approach. We would be checking each question against thousands of others, and in other languages, which will exact a high computational cost. Instead, we can translate the poll titles and see what clusters arise in terms of similarity of meanings. We can them plot them in semantic space and check for clusters.
#
# Then within those clusters, we are far likelier to find questions with overlapping meanings, and finally focus on the ones which are comparable across countries.

# %% [markdown]
# The easy wins here would be findings poll titles that cover the same topic.

# %% [markdown]
# The above assertion came true, which indicates that poll_org and org_id are referring to the same IDs, and each organization has provided a poll at least once.

# %%
# Now let's get the unique questions per poll
questions_by_poll = df.groupby('poll_title')['question_title'].apply(set)
questions_by_poll = pd.DataFrame(questions_by_poll.reset_index())

# %%
questions_by_poll['poll-length'] = questions_by_poll['question_title'].apply(len)
questions_by_poll['poll-length'].describe()
# Out:
# count    4039.000000
# mean        3.818024
# std         2.768573
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         5.000000
# max        27.000000
# Name: poll-length, dtype: float64

# %% [markdown]
# Some polls are more driven by the youth and their concerns, others by what the UN wishes to learn. On average, there are about 3 -4 questions per poll (of course, with outliers).
# There are also fewer

# %%
print(len(df['question_title'].unique()))
print(len(df['question_id'].unique()))
# Out:
# 14542
# 13121

# %%
df.head()
# Out:
#     org_name org_language  org_id  org_host org_subdomain org_domain  poll_id  \
# 0  Argentina           es       8  ilhasoft     argentina        NaN     1734
# 1  Argentina           es       8  ilhasoft     argentina        NaN     1734
# 2  Argentina           es       8  ilhasoft     argentina        NaN     1734
# 3  Argentina           es       8  ilhasoft     argentina        NaN     1734
# 4  Argentina           es       8  ilhasoft     argentina        NaN     1734
#
#                          poll_flow_uuid  \
# 0  5a7577ea-aa1f-4f9c-b031-78ab91695448
# 1  5a7577ea-aa1f-4f9c-b031-78ab91695448
# 2  5a7577ea-aa1f-4f9c-b031-78ab91695448
# 3  5a7577ea-aa1f-4f9c-b031-78ab91695448
# 4  5a7577ea-aa1f-4f9c-b031-78ab91695448
#
#                                           poll_title  poll_org     ...      \
# 0  ¿Cuáles son las redes sociales preferidas por ...         8     ...
# 1  ¿Cuáles son las redes sociales preferidas por ...         8     ...
# 2  ¿Cuáles son las redes sociales preferidas por ...         8     ...
# 3  ¿Cuáles son las redes sociales preferidas por ...         8     ...
# 4  ¿Cuáles son las redes sociales preferidas por ...         8     ...
#
#                                       question_title question_id  \
# 0               ¿Cuál es la red social que más usás?       12689
# 1               ¿Cuál es la red social que más usás?       12689
# 2  ¿Cuánto tiempo por día pasas en la red social ...       12690
# 3  ¿Cuánto tiempo por día pasas entre todas las r...       12691
# 4  ¿Cuánto tiempo por día pasas entre todas las r...       12691
#
#   question_results_open_ended question_order  data_type data_segment_category  \
# 0                       False              1   response              location
# 1                       False              1   response              location
# 2                       False              2  set_unset              location
# 3                       False              3   response              location
# 4                       False              3   response              location
#
#   data_segment_label        data_category_label  data_category_count  \
# 0         Entre Ríos                    Twitter                  0.0
# 1            Córdoba                    Twitter                  0.0
# 2            Mendoza                        set                  0.0
# 3           Santa Fe  Entre 1 y 2 horas por día                  0.0
# 4            Formosa     Más de 4 horas por día                  0.0
#
#    data_order
# 0           6
# 1           6
# 2           0
# 3           2
# 4           4
#
# [5 rows x 26 columns]

# %% [markdown]
# The important point to check here is if the IDs repeat for different questions. So let's use groupby

# %%
#https://kite.com/python/answers/how-to-count-unique-values-in-a-pandas-dataframe-group-in-python
question_by_id = df.groupby(['question_id']).aggregate({'org_language':'nunique'}).reset_index()

# %%
question_by_id
# Out:
#        question_id  org_language
# 0                1             0
# 1                2             0
# 2                3             0
# 3                4             1
# 4                5             1
# 5                6             1
# 6                7             1
# 7                8             0
# 8                9             1
# 9               10             1
# 10              11             0
# 11              12             0
# 12              13             1
# 13              14             2
# 14              15             1
# 15              16             1
# 16              17             2
# 17              18             1
# 18              19             1
# 19              20             1
# 20              21             0
# 21              22             1
# 22              23             0
# 23              24             1
# 24              25             1
# 25              26             0
# 26              27             0
# 27              28             0
# 28              29             0
# 29              30             1
# ...            ...           ...
# 13091        22197             1
# 13092        22199             1
# 13093        22201             1
# 13094        22202             1
# 13095        22203             1
# 13096        22204             1
# 13097        22207             1
# 13098        22208             1
# 13099        22209             1
# 13100        22213             1
# 13101        22214             1
# 13102        22215             1
# 13103        22217             1
# 13104        22227             1
# 13105        22228             1
# 13106        22230             1
# 13107        22259             1
# 13108        22260             1
# 13109        22261             1
# 13110        22267             1
# 13111        22268             1
# 13112        22284             1
# 13113        22285             1
# 13114        22288             1
# 13115        22289             1
# 13116        22292             1
# 13117        22293             1
# 13118        22295             1
# 13119        22296             1
# 13120        22299             1
#
# [13121 rows x 2 columns]

# %%
question_by_id['org_language'].describe()
# Out:
# count    13121.000000
# mean         1.069659
# std          0.456853
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          3.000000
# Name: org_language, dtype: float64

# %% [markdown]
# So on average, a question only gets asked in one language, sometimes less
# The latter option implies that certain polls don't have question associated with them. This might be problematic later.

# %%
#Now the aim is to translate all the questions and find the relevant ones
from googletrans import Translator
translator = Translator()

# %%
result = translator.translate("ไม่ทราบว่าเพื่อนๆ ของยูรีพอร์ตเตอร์มีประสบการณ์ถูกกลั่นแกล้งบนโลกออนไลน์หรือไม่ และทราบหรือไม่ว่าหากพบเห็นการกลั่นแกล้งบนโลกออนไลน์ควรทำอย่างไร?", 
                     src="th", dest="en")

# %%
result.text
# Out:
# "Do not know friends Of Yu-Reporter's experience in cyberbullying? And do you know what to do if you see cyberbullying online?"

# %% [markdown]
# Each poll has an ID with data already generated.
# https://thailand.ureport.in/poll/62

# %%
speaker_countries = df.groupby('org_language')['org_name'].apply(set)
speaker_countries = pd.DataFrame(speaker_countries.reset_index())

# %%
speaker_countries.columns
# Out:
# Index(['org_language', 'org_name'], dtype='object')

# %%
speaker_countries['num_country'] = speaker_countries['org_name'].apply(len)

# %%
for country in speaker_countries[speaker_countries['org_language']=='en']['org_name']:
    print(country)
# Out:
# {'U-Report24x7', 'Lesotho', 'Bangladesh', 'Philippines', 'Ireland', 'Pacific', 'eSwatini', 'Papua New Guinea', 'FSM', 'Botswana', 'Tanzania', 'Uganda', 'Sierra Leone', 'India', 'Ghana', 'Pakistan', 'Malaysia', 'U-Report Global', 'Kiribati', 'Liberia', 'South Africa', 'Belize', 'Jamaica', 'Gambia', 'Malawi', 'Trinidad and Tobago'}

# %% [markdown]
# So the English speaking organizations span quite a range- including groups such as 'Pacific', and more international entities like 'U-Report Global' and 'U-Report 24*7]
# Now we look for the

# %%
non_eng_polls = df[df['org_language'] != 'en'][['poll_title', 'question_title', 
                                                'org_language', 'poll_category_name']]
#It would make sense to remove duplicates

# %%
non_eng_polls.shape
# Out:
# (26776, 4)

# %%
non_eng_polls['poll_category_name'].unique()
# Out:
# array(['Comunicación', 'Inclusión', 'Protección',
#        'Participación Adolescente', 'Educación', 'Salud',
#        'Fechas Importantes', 'Igualdad de Género', 'Cambio Climático',
#        'Adolescencia', 'Participación', 'Niñez', 'embarazo', 'General',
#        'Ureporteri', 'U-Report Brasil', 'Saúde', 'Educação',
#        'ODS 2 - Fome Zero', '+Q',
#        'Objetivos do Desenvolvimento Sustentável', 'ODS', 'Mete a colher',
#        'ODS Geral', 'HIV ', 'Política', 'Migrantes', 'Aprendiz',
#        'Esportes', 'Violência Sexual', 'Evasão Escolar',
#        'Corpo e Gordofobia', 'ODS 5 - Igualdade de Gênero', 'Corpo',
#        'Redução', 'Juv e Trabalho', 'Direitos Reprodutivos e Prevenções',
#        'Proteção', "ODS 14 - Vida debaixo D'Água",
#        'ODS 9 - Indústria, Inovação e Infraestrutura',
#        'ODS 3 - Saúde e Bem-Estar', 'ODS 1 - Erradicação da Pobreza',
#        'Abordagem Policial', 'Acesso à justiça', 'ARMAS', 'DROGAS',
#        'Rede LGBT', 'Letalidade Violenta', 'Segurança', 'S4D', 'Opinions',
#        'Participation', 'Education', 'Santé', 'Cybercrime', 'Nutrition',
#        'Hygiène', "Droits de l'enfant", 'Général',
#        'Eau, Assainissement et Hygiène', "Protection de l'enfant",
#        'Environnement', 'Helpline', 'Sustentabilidad', 'Contingencia',
#        'Politique Social', 'Jeunesse', 'Jeunessse  / Adolescence',
#        'Enfance', 'U-Report', 'Opiniones', 'Participation des jeunes',
#        'Protection ', 'Eau et hygiène', 'VIH/Sida', "Droits de l'Homme",
#        'Emploi', 'Média', 'Diplomatie', 'Consommation', 'Politique',
#        'Sports', 'Économie et finances', 'Innovations',
#        'Santé reproductive sexuelle', 'Culture', 'Emergencia',
#        'Emergencias', 'Políticas Sociales', 'Zika', 'Internet',
#        'Éducation', 'Citoyenneté', 'Protection', 'Engagement/solidarité',
#        'Sport', 'Inégalités', "Radio Mouv'", 'Agua y sanimiento',
#        'Salud Adolescente', 'Protección ', 'U-Report Guatemala',
#        'Participación adolescente', 'Uso de tiempo libre',
#        'Cambio Climático 2', 'Primera Infancia', 'Matrimonio infantil',
#        'Embarazo adolescente', 'Objetivos de Desarrollo Sostenible (ODS)',
#        'SANTÉ ', 'GOUVERNANCE', 'POLITIQUES SOCIALES (Social inclusion)',
#        'EDUCATION', 'Wash', 'SPORT', 'VIH/ SIDA',
#        "PROTECTION DE L'ENFANT", 'Communcation Externe',
#        'Droits des enfants', 'Niñez y adolescencia', 'Join & Engage',
#        'Redes sociales', 'Políticas', 'Innovation', 'ADAP',
#        'Child Protection', 'Social Policy', 'HIV/AIDS', 'Immunization',
#        'Children on the Move', 'Derechos', 'Tecnología', 'Alte sondaje',
#        'Sănătate și bunăstare', 'Media și tehnologie',
#        'Educație și viața școlară', 'Drepturile copiilor & monitorizare',
#        'Carieră', 'Monitorizarea drepturilor',
#        'Obiectivele de Dezvoltare Durabilă', 'Participare si dezvoltare',
#        'Protecția copilului', 'Mediu înconjurător',
#        'CORONAVIRUS 2019 - (COVID-19)', 'EMPREGO', 'Ouro Negro',
#        'Inquérito de Satisfação sobre Serviços de SSR - 09 Dec 2019',
#        'Child Protection - Bilhete de Identidade',
#        'Ciclone IDAI e Cheias', 'Campanha de Vacinacao do Polio',
#        'Social Mobilizers_WASH Interventions',
#        'CIDADES AMIGAS DAS CRIANCAS', 'Saúde Materna Infantil',
#        'Pré-Campanha sobre a Pólio - 28 a 29 de Janeiro 2018',
#        'São Valentim - Dia dos Namorados',
#        'Inquérito de Satisfação sobre Serviços de SSR - SOFH 15.12.18',
#        'World Children Day 20th November 2018',
#        'Radionovela os Intxunáveis',
#        'Prevencao do consumo de alcool, tabaco e drogas  ilegais.',
#        'Inquérito Global sobre os Cuidados de Saúde Primários',
#        'Violencia nas escolas', 'Dia Internacional do Albinismo',
#        'DIA MUNDIAL DA CRIANÇA', 'DIA INTERNACIONAL DA MULHER',
#        'HIV, TRANSMISSÃO, PREVENÇÃO, TRATAMENTO',
#        'ADESÃO AS UNIDADES SANITÁRIAS', 'SMS BIZ - COMO USAR',
#        'Higiene Menstrual - 28 Maio', 'SAÚDE SEXUAL E REPRODUTIVA',
#        'EDUCAÇÃO', 'Violência contra as Raparigas',
#        'Casamentos Prematuros', 'Violência contra Menores', 'Comunicação',
#        'MALARIA', 'RELACIONAMENTOS', 'SEXUALIDADE', 'Health',
#        'Climate Change', 'Governance', 'Youth & Digital', 'Youth',
#        'Disaster', 'Infrastructure', 'Child protection',
#        'Peace and Social Cohesion', 'Gender', 'Employment',
#        'Youth policy', 'U-reporters General', 'Outbreaks',
#        'Water and Sanitation', 'Advocacy 4', 'Ureport & Policy Makers ',
#        'GIRL CHILD ', 'SDGs', 'Innovation ', "Partner's poll",
#        'OVP polls', 'Global poll', 'Polio comms', 'FMoH/NPHCDA',
#        'COVID19', 'Diritti', 'Emergenza', 'Coinvolgimento giovani',
#        'Hate speech', 'Aspirazioni', 'Scuola', 'Accesso ai servizi',
#        'Tolleranza', 'Orientamento Professionale',
#        'Sistema di accoglienza', 'Informazioni legali',
#        'Attività ricreative', 'Ambiente', 'Sondaje', 'Paix',
#        'Santé- Wash', 'Santé et Nutrition', 'U-Report Senegal',
#        'Plaidoyer et Participation', 'VIH/SIDA',
#        'Emploi et Entrepreneuriat ', 'Zaštita životne sredine',
#        'Obrazovanje', 'Ankete', 'Bezbednost', 'Obrada podataka',
#        'Prioriteti mladih', 'Ishrana', 'Zapošljavanje', 'Informisanje',
#        'Ravnopravnost', 'Prevencija nasilja', 'Communication', 'Sante',
#        'Hygiene', 'Entreprenariat', 'Changement Climatique', 'Polio',
#        'Volontariat en Tunisie', "Lutte contre l'abandon scolaire",
#        'Journée mondiale des enfants',
#        "Journée mondiale des enfants (World Children's Day)",
#        "Violence à l'égard des enfants et adolescents", 'Migration',
#        'Citoyenneté mondiale', 'Transport scolaire', 'Sujets U-Report',
#        "Ta'lim / Образование", 'Jamiyat / Общество',
#        "Sog'liqni saqlash / Здравоохранение", 'Ish / Работа',
#        'Innovatsiya / Инновация', 'Yoshlar / Молодежь',
#        "Bo'sh vaqt / Досуг", 'Ijtimoiy masalalar / Социальные вопросы',
#        'Cyber Bullying', 'Bạo lực công cộng', 'Bạo lực gia đình',
#        'School bullying', 'U-Report Albania - Local Polls',
#        'Kosovo Local Polls', 'Montenegro Local Polls',
#        'U-Report Western Balkans', 'Youth Engagement', 'WASH',
#        'Climate and Environment', 'Освіта',
#        'SDGs - Цілі сталого розвитку', 'LifeStyle', "Здоров'я",
#        'Загальні', 'Саморозвиток', '#EndViolence - Протидія насильству',
#        'Урбаністика', 'U-Report у світі', 'Мистецтво',
#        'Гендерна рівність', 'New Year', 'ВІЛ/СНІД',
#        'Corona Virus Response', 'Child Rights', 'Mental Health',
#        'Well Being', 'Poll', 'Violence Against Children', 'เสียงเยาวชน',
#        'การคุ้มครองเด็ก', 'การศึกษา', 'อื่นๆ',
#        'นโยบายสังคม และ งานรณรงค์', 'เอชไอวี/เอดส์', 'Other images',
#        'สุขภาพ', 'สิทธิเด็ก', 'สถานการณ์ฉุกเฉิน', 'ความเหลื่อมล้ำ'],
#       dtype=object)

# %% [markdown]
# We have gone from 40,000 or so question 26.7k- which indicates that though the number of countries for non-English speaking countries may be less, they stil involve a considerable proportion of the total questions. How many from Spain?

# %%
@non_eng_polls.drop_duplicates(inplace=True)
non_eng_polls.shape

# %%
#Translating the Poll Titles
# Out:
# (10796, 4)

# %%
non_eng_polls.loc[non_eng_polls['org_language']=='fr']
# Out:
#                                               poll_title  \
# 2304   Perception des adolescent-e-s et jeunes sur le...
# 2305   Perception des adolescent-e-s et jeunes sur le...
# 2306   Perception des adolescent-e-s et jeunes sur le...
# 2307   Perception des adolescent-e-s et jeunes sur le...
# 2308   Perception des adolescent-e-s et jeunes sur le...
# 2309   Rétro information sur l'Etat Civil dans la rég...
# 2310   Rétro information sur l'Etat Civil dans la rég...
# 2311   Rétro information sur l'Etat Civil dans la rég...
# 2312   Rétro information sur l'Etat Civil dans la rég...
# 2313   Rétro information sur l'Etat Civil dans la rég...
# 2314   Participation des adolescents et jeunes [Mars ...
# 2315   Participation des adolescents et jeunes [Mars ...
# 2316   Participation des adolescents et jeunes [Mars ...
# 2317   Participation des adolescents et jeunes [Mars ...
# 2318   Participation des adolescents et jeunes [Mars ...
# 2319   Participation des adolescents et jeunes [Mars ...
# 2320   Participation des adolescents et jeunes [Mars ...
# 2321   Participation des adolescents et jeunes [Mars ...
# 2322   Participation des adolescents et jeunes [Mars ...
# 2323   Participation des adolescents et jeunes [Mars ...
# 2324   Participation des adolescents et jeunes [Mars ...
# 2325   Participation des adolescents et jeunes [Mars ...
# 2326   Participation des adolescents et jeunes [Mars ...
# 2327   Education des filles au post-primaire et secon...
# 2328   Education des filles au post-primaire et secon...
# 2329   Education des filles au post-primaire et secon...
# 2330   Education des filles au post-primaire et secon...
# 2331   Education des filles au post-primaire et secon...
# 2332   Education des filles au post-primaire et secon...
# 2333   Education des filles au post-primaire et secon...
# ...                                                  ...
# 32074                       Prise en charge de l'Urgence
# 32075                       Prise en charge de l'Urgence
# 32076                           Préoccupation principale
# 32077                           Préoccupation principale
# 32078                           Préoccupation principale
# 32079                             L'ordinateur à l'école
# 32080                             L'ordinateur à l'école
# 32081                             L'ordinateur à l'école
# 32082                          L'approche par compétence
# 32083                          L'approche par compétence
# 32084  Aujourd'hui, qu'est-ce qui te préoccupe le plus ?
# 32085                    Sensibilisation sur le VIH/SIDA
# 32086                    Sensibilisation sur le VIH/SIDA
# 32087                    Sensibilisation sur le VIH/SIDA
# 32088                    Sensibilisation sur le VIH/SIDA
# 32089                    Sensibilisation sur le VIH/SIDA
# 32090                    Sensibilisation sur le VIH/SIDA
# 32091                    Sensibilisation sur le VIH/SIDA
# 32092  Depuis Ébola au Mali, as-tu peur de te rendre ...
# 32093  Depuis Ébola au Mali, as-tu peur de te rendre ...
# 32094  As tu un ami qui envisage de quitter l’école c...
# 32095  As tu un ami qui envisage de quitter l’école c...
# 32096  As tu un ami qui envisage de quitter l’école c...
# 32097  As tu un ami qui envisage de quitter l’école c...
# 32098  As tu un ami qui envisage de quitter l’école c...
# 32099   Quels sujets aimerais tu aborder sur U-report ?
# 32100   Quels sujets aimerais tu aborder sur U-report ?
# 32101   Quels sujets aimerais tu aborder sur U-report ?
# 32102   Quels sujets aimerais tu aborder sur U-report ?
# 32103   Quels sujets aimerais tu aborder sur U-report ?
#
#                                           question_title org_language  \
# 2304                                 [Si non] Pourquoi ?           fr
# 2305                         Quelles mesures prends-tu ?           fr
# 2306                         Quelles mesures prends-tu ?           fr
# 2307   Comment reçois-tu les informations sur le coro...           fr
# 2308   Comment reçois-tu les informations sur le coro...           fr
# 2309   Est-ce que la délivrance de la copie d’acte de...           fr
# 2310   Combien de fois doit-on se rendre dans la comm...           fr
# 2311   Comment jugez-vous l’accueil dans les services...           fr
# 2312   Comment jugez-vous l’accueil dans les services...           fr
# 2313   Comment jugez-vous l’accueil dans les services...           fr
# 2314   Penses-tu que l’avis des jeunes sur les sujets...           fr
# 2315   Penses-tu que l’avis des jeunes sur les sujets...           fr
# 2316             [Si non] pour quelle raison selon toi ?           fr
# 2317             [Si non] pour quelle raison selon toi ?           fr
# 2318             [Si non] pour quelle raison selon toi ?           fr
# 2319   Pour toi, que signifie la participation des je...           fr
# 2320   [Si autres] Dis-nous selon toi que signifie la...           fr
# 2321   Parmi ces thématiques, sur laquelle souhaitera...           fr
# 2322   Parmi ces thématiques, sur laquelle souhaitera...           fr
# 2323   Parmi ces thématiques, sur laquelle souhaitera...           fr
# 2324   [Si autres] Dis-nous sur quelle autre thématiq...           fr
# 2325   [Si autres] Dis-nous sur quelle autre thématiq...           fr
# 2326   A ton avis, qu’est-ce qui devrait être fait po...           fr
# 2327   Penses-tu qu’il est important pour une fille d...           fr
# 2328   Penses-tu qu’il est important pour une fille d...           fr
# 2329   Selon toi, qu’est-ce qui empêche les filles de...           fr
# 2330   Selon toi, qu’est-ce qui empêche les filles de...           fr
# 2331   Selon-toi est-ce que les garçons ont accès plu...           fr
# 2332   Selon-toi est-ce que les garçons ont accès plu...           fr
# 2333   Selon toi est-ce que de plus en plus, les pare...           fr
# ...                                                  ...          ...
# 32074  Qui t'attends tu à voir aider les populations ...           fr
# 32075      Étais-tu satisfait de l'aide que tu as reçu ?           fr
# 32076  Aujourd'hui, qu'est ce qui te préoccupe le plus ?           fr
# 32077  Aujourd'hui, qu'est ce qui te préoccupe le plus ?           fr
# 32078  Aujourd'hui, qu'est ce qui te préoccupe le plus ?           fr
# 32079  Est-ce que cette utilisation a un impact posit...           fr
# 32080    Quel outil utilises-tu le plus pour apprendre ?           fr
# 32081    Quel outil utilises-tu le plus pour apprendre ?           fr
# 32082  Connais tu le nouveau système éducatif APC (Ap...           fr
# 32083  Connais tu le nouveau système éducatif APC (Ap...           fr
# 32084  Aujourd'hui, qu'est-ce qui te préoccupe le plus ?           fr
# 32085                     Combien as tu de partenaires ?           fr
# 32086         As tu déjà fais un dépistage du VIH/SIDA ?           fr
# 32087                    Pourquoi t'es tu fais dépisté ?           fr
# 32088           Pourquoi n'as tu pas fais le dépistage ?           fr
# 32089        Comment te protèges tu contre le VIH/SIDA ?           fr
# 32090        Comment te protèges tu contre le VIH/SIDA ?           fr
# 32091        Comment te protèges tu contre le VIH/SIDA ?           fr
# 32092  Si tu tombes malade aujourd'hui, tu préfères a...           fr
# 32093  Si tu tombes malade aujourd'hui, tu préfères a...           fr
# 32094  Connais-tu un ami qui envisage de quitter l’éc...           fr
# 32095                    Est ce une fille ou un garçon ?           fr
# 32096           Quelles sont les causes de son abandon ?           fr
# 32097           Quelles sont les causes de son abandon ?           fr
# 32098           Quelles sont les causes de son abandon ?           fr
# 32099  Sur quel sujet aimerais tu discuter sur U-Repo...           fr
# 32100  Sur quel sujet aimerais tu discuter sur U-Repo...           fr
# 32101             Comment voudrais tu partager U-Report?           fr
# 32102             Comment voudrais tu partager U-Report?           fr
# 32103                              Quelles autres Media?           fr
#
#       poll_category_name
# 2304       Participation
# 2305       Participation
# 2306       Participation
# 2307       Participation
# 2308       Participation
# 2309       Participation
# 2310       Participation
# 2311       Participation
# 2312       Participation
# 2313       Participation
# 2314       Participation
# 2315       Participation
# 2316       Participation
# 2317       Participation
# 2318       Participation
# 2319       Participation
# 2320       Participation
# 2321       Participation
# 2322       Participation
# 2323       Participation
# 2324       Participation
# 2325       Participation
# 2326       Participation
# 2327           Education
# 2328           Education
# 2329           Education
# 2330           Education
# 2331           Education
# 2332           Education
# 2333           Education
# ...                  ...
# 32074            Général
# 32075            Général
# 32076            Général
# 32077            Général
# 32078            Général
# 32079          Éducation
# 32080          Éducation
# 32081          Éducation
# 32082          Éducation
# 32083          Éducation
# 32084            Général
# 32085              Santé
# 32086              Santé
# 32087              Santé
# 32088              Santé
# 32089              Santé
# 32090              Santé
# 32091              Santé
# 32092              Santé
# 32093              Santé
# 32094          Éducation
# 32095          Éducation
# 32096          Éducation
# 32097          Éducation
# 32098          Éducation
# 32099            Général
# 32100            Général
# 32101            Général
# 32102            Général
# 32103            Général
#
# [3512 rows x 4 columns]

# %%
non_english_polls['translated_category'] = non_eng_polls.progress_apply(lambda x: translate_to_eng(x.poll_category_name, x.org_language),
                                                       axis=1)
# Out:
#   0%|                                                                             | 2/26776 [00:18<70:27:51,  9.47s/it]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-2f8dfa826e5c> in translate_to_eng(txt, src_lang)
#       8         result = translator.translate(txt,
# ----> 9                      src=src_lang, dest="en")
#      10     #In case the organization's language label doesn't match the question language
#
# ~\Anaconda3\lib\site-packages\googletrans\client.py in translate(self, text, dest, src, **kwargs)
#     181         origin = text
# --> 182         data = self._translate(text, dest, src, kwargs)
#     183
#
# ~\Anaconda3\lib\site-packages\googletrans\client.py in _translate(self, text, dest, src, override)
#      77     def _translate(self, text, dest, src, override):
# ---> 78         token = self.token_acquirer.do(text)
#      79         params = utils.build_params(query=text, src=src, dest=dest,
#
# ~\Anaconda3\lib\site-packages\googletrans\gtoken.py in do(self, text)
#     193     def do(self, text):
# --> 194         self._update()
#     195         tk = self.acquire(text)
#
# ~\Anaconda3\lib\site-packages\googletrans\gtoken.py in _update(self)
#      61         # this will be the same as python code after stripping out a reserved word 'var'
# ---> 62         code = self.RE_TKK.search(r.text).group(1).replace('var ', '')
#      63         # unescape special ascii characters such like a \x3d(=)
#
# AttributeError: 'NoneType' object has no attribute 'group'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-297bdcbfb6b5> in <module>()
#       1 non_english_polls['translated_category'] = non_eng_polls.progress_apply(lambda x: translate_to_eng(x.poll_category_name, x.org_language),
# ----> 2                                                        axis=1)
#
# ~\AppData\Roaming\Python\Python36\site-packages\tqdm\std.py in inner(df, func, *args, **kwargs)
#     765                 # on the df using our wrapper (which provides bar updating)
#     766                 try:
# --> 767                     return getattr(df, df_function)(wrapper, **kwargs)
#     768                 finally:
#     769                     t.close()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6002                          args=args,
#    6003                          kwds=kwds)
# -> 6004         return op.get_result()
#    6005
#    6006     def applymap(self, func):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# ~\AppData\Roaming\Python\Python36\site-packages\tqdm\std.py in wrapper(*args, **kwargs)
#     760                     # take a fast or slow code path; so stop when t.total==t.n
#     761                     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 762                     return func(*args, **kwargs)
#     763
#     764                 # Apply the provided function (in **kwargs)
#
# <ipython-input-33-297bdcbfb6b5> in <lambda>(x)
# ----> 1 non_english_polls['translated_category'] = non_eng_polls.progress_apply(lambda x: translate_to_eng(x.poll_category_name, x.org_language),
#       2                                                        axis=1)
#
# <ipython-input-9-2f8dfa826e5c> in translate_to_eng(txt, src_lang)
#      10     #In case the organization's language label doesn't match the question language
#      11     except:
# ---> 12         result = translator.translate(txt, dest="en")
#      13
#      14     return result.text
#
# ~\Anaconda3\lib\site-packages\googletrans\client.py in translate(self, text, dest, src, **kwargs)
#     180
#     181         origin = text
# --> 182         data = self._translate(text, dest, src, kwargs)
#     183
#     184         # this code will be updated when the format is changed.
#
# ~\Anaconda3\lib\site-packages\googletrans\client.py in _translate(self, text, dest, src, override)
#      76
#      77     def _translate(self, text, dest, src, override):
# ---> 78         token = self.token_acquirer.do(text)
#      79         params = utils.build_params(query=text, src=src, dest=dest,
#      80                                     token=token, override=override)
#
# ~\Anaconda3\lib\site-packages\googletrans\gtoken.py in do(self, text)
#     192
#     193     def do(self, text):
# --> 194         self._update()
#     195         tk = self.acquire(text)
#     196         return tk
#
# ~\Anaconda3\lib\site-packages\googletrans\gtoken.py in _update(self)
#      60
#      61         # this will be the same as python code after stripping out a reserved word 'var'
# ---> 62         code = self.RE_TKK.search(r.text).group(1).replace('var ', '')
#      63         # unescape special ascii characters such like a \x3d(=)
#      64         code = code.encode().decode('unicode-escape')
#
# AttributeError: ("'NoneType' object has no attribute 'group'", 'occurred at index 0')

# %% [markdown]
# #### Deduplication
# So we have only 10.7k entries now- which suggests about 2-3 duplicates for questions earlier

# %%
#let's check if it's the same number of questions for all languages
poll_by_lang = df.groupby(['org_language'])['poll_title'].count()

# %%
poll_by_lang
#So more or less, we have the same number of poll_titles as question_titles
# Therefore, Only one question per poll
# So polls themselves aren't going to be very useful
# Out:
# org_language
# ar               104
# bg                 7
# bs                72
# en             17903
# es              4360
# fr              3512
# id              1512
# it               456
# my              2702
# pt               461
# pt-br           1088
# ro              2046
# sr-rs@latin     1100
# th              2723
# uk              2657
# uz               954
# vi                32
# Name: poll_title, dtype: int64

# %%
poll_by_lang_poll = df.groupby(['org_language', 'poll_title'])['question_title'].count()

# %%
poll_by_lang_poll.reset_index()
# Out:
#      org_language                                         poll_title  \
# 0              ar  COVID-19 Risk Perception at Community Level Su...
# 1              ar                         COVID19 Information centre
# 2              ar                                                CRC
# 3              ar                             Ending Violence Online
# 4              ar                    Impact of COVID-19 on Education
# 5              ar                                     Mira: Movement
# 6              ar                             Safe Internet Day Poll
# 7              ar                         U-Report For Syria 9 Years
# 8              ar               World Mental Health Day - 10 October
# 9              ar                            الصحة النفسية والرفاهية
# 10             ar                         مستقبل - Youth Aspirations
# 11             bg  Най-значимите проблеми на децата и младите хор...
# 12             bs                                  16 dana aktivizma
# 13             bs  Adekvatno informisanje o situaciji vezanoj za ...
# 14             bs                         Anketa o PISA istraživanju
# 15             bs                     Anketa o klimatskim promjenama
# 16             bs         Anketa o kulturi dijaloga i izgradnji mira
# 17             bs    Anketa o rodnim ulogama, stereotipima i nasilju
# 18             bs  Anketa povodom međunarodnog dana smanjenja riz...
# 19             bs                             COVID 19 i obrazovanje
# 20             bs      Da li ti želiš napustiti Bosnu i Hercegovinu?
# 21             bs   Kako se mladi osjećaju tokom COVID-19 pandemije?
# 22             bs                              Koliko znamo o nauci?
# 23             bs                     Korištenje mobilnih aplikacija
# 24             bs     Mentalno zdravlje u vrijeme pandemije Covid-19
# 25             bs                          Međunarodni dan žena 2019
# 26             bs                                     Online nastava
# 27             bs                                 Poslovi budućnosti
# 28             bs                   Prioritetna pitanja mladih u BiH
# 29             bs                                Sedmica imunizacije
# ...           ...                                                ...
# 3628           uz  Startaplarni qanday rivojlantirish kerak? / Ка...
# 3629           uz  U-Report haqida fikringiz qanday? / Что Ты дум...
# 3630           uz  U-Report haqida nima deysiz? / Что Ты скажешь ...
# 3631           uz  U-Reportda nima haqida muloqot qilmoqchisiz? /...
# 3632           uz  Yangi yil bayramini yoshlar qanday nishonlasha...
# 3633           uz  Yomon odatlaringiz bormi? / Есть ли у Тебя вре...
# 3634           uz  Yoshlar YHQ ni yetarli darajada yahshi biladim...
# 3635           uz  Yoshlar ishlari Agentligi qanday bo’lishi kera...
# 3636           uz  Yoshlar kitob o’qishadimi? / Читает ли молодеж...
# 3637           uz  Yoshlar kontrasepsiya haqida nima bilishadi? /...
# 3638           uz  Yoshlar o’z biznesini olib borishga tayyormi? ...
# 3639           uz  Yoshlar qabul qilinayotgan qonunlar haqida xab...
# 3640           uz  Yoshlar qanday videolarga qiziqmoqdalar? / Как...
# 3641           uz  Yoshlar uchun kasbiy yo’naltirish / Профориент...
# 3642           uz  Yoshlar “Yoshlar - kelajagimiz” Davlat dasturi...
# 3643           uz  Yoshlarni oilaviy munosabatlarni qurishga aloh...
# 3644           uz  Yoshlarning davlat / jamiyat ijtimoiy-siyosiy ...
# 3645           uz  Yoshlarning ijtimoiy faolligi / Социальная акт...
# 3646           uz  Yoshlarning ijtimoiy faolligi / Социальная акт...
# 3647           uz  Yoshlarning jamiyat hayotidagi ishtiroki / Уча...
# 3648           uz  Yoshlarning mediya va axborot savodxonligi / М...
# 3649           uz  Yozni qanday o’tkazmoqdasiz? / Как ты проводиш...
# 3650           uz  “Harakatlar Strategiyasi: kelajak istiqbollari...
# 3651           vi  Bạn biết gì về tình trạng bắt nạt tại trường học?
# 3652           vi                                  Bạo lực trên mạng
# 3653           vi       Bắt nạt trên mạng - Bạn có phải là nạn nhân?
# 3654           vi     Bắt nạt tại trường học - Bạn đã từng trải qua?
# 3655           vi  Khi ở trên đường phố, bến xe hay các địa điểm ...
# 3656           vi  Người trẻ nghĩ gì về tình trạng bạo lực đối vớ...
# 3657           vi                    Thành phố thân thiện với trẻ em
#
#       question_title
# 0                 15
# 1                 23
# 2                  8
# 3                 12
# 4                  5
# 5                  2
# 6                  1
# 7                 12
# 8                  2
# 9                 10
# 10                14
# 11                 7
# 12                 3
# 13                 2
# 14                 3
# 15                 1
# 16                 8
# 17                 2
# 18                 3
# 19                 3
# 20                 4
# 21                 5
# 22                 6
# 23                 3
# 24                 3
# 25                 2
# 26                 1
# 27                 4
# 28                 4
# 29                 2
# ...              ...
# 3628              15
# 3629              13
# 3630               9
# 3631               1
# 3632              11
# 3633              20
# 3634               8
# 3635              18
# 3636               7
# 3637              15
# 3638              15
# 3639              12
# 3640               9
# 3641              13
# 3642              17
# 3643              15
# 3644               2
# 3645              11
# 3646              13
# 3647              21
# 3648               8
# 3649              17
# 3650              23
# 3651               3
# 3652               9
# 3653               2
# 3654               3
# 3655               9
# 3656               2
# 3657               4
#
# [3658 rows x 3 columns]

# %% [markdown]
# #### Translation
# Now we can can use the Translator object to get the vast range of translations

# %%
def translate_to_eng(txt, src_lang):
    """
    takes in text in a non-english language
    returns the english translation
    """
    
    try:
        print('it worked')
        result = translator.translate(txt, 
                     src=src_lang, dest="en")
    #In case the organization's language label doesn't match the question language
    except:
        result = translator.translate(txt, dest="en")
        
    return result.text

# %%
def translate_unknown_to_eng(txt):
    """
    takes in text in a non-english language (not specified by user)
    returns the english translation
    """
    
    try:
        result = translator.translate(txt,
                                    dest="en")
        return result.text
    #In case the organization's language label doesn't match the question language
    except:
        return ""

# %%
_only_uniq_categs = non_eng_polls.drop_duplicates(subset=['org_language', 'poll_category_name'])

# %%
_only_uniq_categs.shape
# Out:
# (316, 4)

# %% [markdown]
# How is this not equal to the unique values across just the poll categories? There may some poll titles which are the same even across languages. How is that acceptable for us?

# %%
_only_uniq_categs
# Out:
#                                               poll_title  \
# 0      ¿Cuáles son las redes sociales preferidas por ...
# 6      ¿Cómo afecta el Aislamiento Preventivo Social ...
# 57     ¿Cómo es la situación en el hogar de los adole...
# 67     Covid-19: ¿Qué acciones pueden tomar los adole...
# 96         Educación a Distancia en contexto de Covid-19
# 118        Actitudes y comportamientos sobre el COVID-19
# 150                        Día Internacional de la Mujer
# 313      #DíaDeLaNiña ¿Cuál es el trabajo de tus sueños?
# 352                                     Cambio Climático
# 978    COVID 19 - Actitudes y comportamientos durante...
# 1001                    Rumbo a la pacificación del país
# 1026   La Convención sobre los derechos del niño y la...
# 1042   Un 14% de los nacimientos en Bolivia es de mad...
# 1099                              COVID 19 i obrazovanje
# 1113                          Anketa o PISA istraživanju
# 1209         Uso da internet durante o isolamento social
# 1233   Adolescentes e jovens diante da pandemia de co...
# 1307   Acesso ao ensino superior | Pesquisadores Soci...
# 1353                                 Nutrição 2 | UNICEF
# 1393                                 Voluntariado UNICEF
# 1397   Cidades Amigas das Crianças | Child Friendly C...
# 1404                            Contra violência online!
# 1452      Uma colherada na relação abusiva e violências!
# 1461                   Amém Axé | Intolerância Religiosa
# 1491                                      Combate ao HIV
# 1503                Quem decide o que se fala na escola?
# 1509                           Refugiados y migrantes II
# 1561   U-Report pergunta: E a Lei da Aprendizagem, ju...
# 1638               Direito ao Esporte Seguro e Inclusivo
# 1650                                          MandaNude!
# ...                                                  ...
# 39223                                         Енергетика
# 39267                              Святкування Великодня
# 39271                                Молодь на карантині
# 39319                        Відчуття безпеки (повторне)
# 39447                            Молодіжні події (Луцьк)
# 39606                                 Домашнє насильство
# 39620                  Відїзд молоді з міста (Маріуполь)
# 39709  Вплив молоді у місті (Засідання мерів щодо діт...
# 39751                           Центри культурних послуг
# 40934   Виклики для дівчат і жінок (сільська місцевість)
# 41039                               Новорічне опитування
# 41073                            День боротьби зі СНІДом
# 41867                    Impact of COVID-19 on Education
# 41872  COVID-19 Risk Perception at Community Level Su...
# 41910                                                CRC
# 41918               World Mental Health Day - 10 October
# 41920                            الصحة النفسية والرفاهية
# 41930                         مستقبل - Youth Aspirations
# 41944                             Ending Violence Online
# 41956  เราได้ร่วมมือกับองค์การแรงงานระหว่างประเทศ (IL...
# 41983  เรามีโพลสำรวจใหม่มาฝากให้วัยรุ่นช่วยแสดงความคิ...
# 42034  เรายังคงสำรวจความคิดเห็นของวัยรุ่นเกี่ยวกับเรื...
# 42154                               Dare to Dream Poll 1
# 42268  เราอยากรู้ว่าวัยรุ่นไทยสนใจงานด้านอาสาสมัครมาก...
# 42348  เราได้ร่วมมือกับมูลนิธิ Path2Health เพื่อสำรวจ...
# 42397  เราได้จับมือกับสำนักงานกองทุนสนับสนุนการสร้างเ...
# 42548  ทุกปียูนิเซฟจะจัดทำรายงานสภาวะเด็กโลก ซึ่งสำรว...
# 42572  เราได้ร่วมมือกับกลุ่มการศึกษาเพื่อความเป็นไทอี...
# 43915  ภัยพิบัติต่างๆ สร้างความสูญเสียแก่ชุมชนและครอบ...
# 44480  เด็กที่อยู่ในครอบครัวยากจน จะขาดโอกาสในหลายๆ ด...
#
#                                           question_title org_language  \
# 0                   ¿Cuál es la red social que más usás?           es
# 6      Mencione los tres cambios más importantes en l...           es
# 57     Durante la cuarentena, ¿quién hace la mayor pa...           es
# 67                 ¿Qué tipo de acciones querés conocer?           es
# 96     Para quienes se encuentran estudiando actualme...           es
# 118       ¿Cómo te has sentido estos últimos siete días?           es
# 150    ¿Considerás que las mujeres deberían tener igu...           es
# 313                   ¿Cuál es el trabajo de tus sueños?           es
# 352    ¿Considerás que a través de tus acciones podés...           es
# 978    ¿Qué opción describe mejor cómo te has sentido...           es
# 1001   ¿Qué te causó más molestia o preocupación dura...           es
# 1026      ¿Sabes a quién protegen los derechos del niño?           es
# 1042         ¿Conoces casos de adolescentes embarazadas?           es
# 1099   Koliko vremena dnevno provodiš prateći i radeć...           bs
# 1113               Da li si čuo-la za PISA istraživanje?           bs
# 1209          De qual forma você mais acessa a internet?        pt-br
# 1233                           Você mora em uma capital?        pt-br
# 1307                              Quantos anos você tem?        pt-br
# 1353   Quais são os tipos de alimentos ofertados na m...        pt-br
# 1393   Você está interessado em trabalhar como volunt...        pt-br
# 1397   Os políticos da sua cidade escutam a opinião d...        pt-br
# 1404                 Is there a helpline in your country        pt-br
# 1452   Meninos | Você sente que possui espaços seguro...        pt-br
# 1461        Já ouviu falar sobre intolerância religiosa?        pt-br
# 1491   Você sabe onde pode realizar o exame gratuitam...        pt-br
# 1503   Você acha que a escola é um espaço importante ...        pt-br
# 1509   Q8 would you advise your family members or fri...        pt-br
# 1561   Você acha importante ter uma lei que garanta o...        pt-br
# 1638   A escola possui equipamentos para prática espo...        pt-br
# 1650   Você conhece alguém que tenha tido fotos íntim...        pt-br
# ...                                                  ...          ...
# 39223  Чи знаєте Ви, з яких джерел виробляється елект...           uk
# 39267                 Як Ви плануєте провести Великдень?           uk
# 39271  Наскільки комфортно психологічно Вам знаходити...           uk
# 39319  Яке ваше внутрішнє сприйняття рівня безпеки в ...           uk
# 39447  Як часто Ви відвідуєте невеликі (до 50 людей) ...           uk
# 39606  Чи стикалися Ви з домашнім насильством щодо Ва...           uk
# 39620  Чи маєте Ви намір покинути місто на тривалий час?           uk
# 39709  На Вашу думку, якими були б найефективніші мех...           uk
# 39751  Як часто Ви відвідуєте заклади культури (біблі...           uk
# 40934  У яких сферах є найбільші виклики для дівчат і...           uk
# 41039                        Де Ви зустрічали Новий рік?           uk
# 41073  Чи хочете Ви взяти участь в опитуванні до Всес...           uk
# 41867  ?Were you at school before the current movemen...           ar
# 41872                        ?Have you heard of COVID-19           ar
# 41910         كم دولة صدقت على اتفاقية حقوق الطفل (CRC)؟           ar
# 41918  برأيك، ما هي الأسباب التي تمنع الأشخاص من الحص...           ar
# 41920  هل تعتقد أنه يجب بذل المزيد من الجهد لتعليم وت...           ar
# 41930  مرحبًا، نود أن نعرف ما هى الأفكار التي تدور في...           ar
# 41944  هل كانت الحالة: \r\r\nنشر على العلن عبر الانتر...           ar
# 41956  น้องๆ คิดว่าประเทศไทยต้องการแรงงานข้ามชาติหรือ...           th
# 41983                              Are u ready to answer           th
# 42034  ตอนนี้น้องๆ มีความมั่นใจไหมคะว่าจะสามารถมีชีวิ...           th
# 42154  น้องๆ คิดว่าตัวน้องเองต้องเร่งพัฒนาความสามารถด...           th
# 42268             น้อง ๆ ชอบทำกิจกรรมอาสาสมัครกันไหมครับ           th
# 42348                    น้องๆ เคยขอถุงยางอนามัยฟรีไหมคะ           th
# 42397             ปกติน้องๆ เล่นเกมออนไลน์บ่อยแค่ไหนครับ           th
# 42548  น้องๆ คิดว่าปกติตัวเองกินอาหารอย่างระวังสุขภาพ...           th
# 42572  สิทธิขั้นพื้นฐานในสถานศึกษาด้านไหนที่น้องอยากไ...           th
# 43915  น้องๆ คิดว่าตนเองมีความรู้เรื่องการเตรียมความพ...           th
# 44480  น้องๆ คิดว่า ในชุมชนที่น้องอยู่ มีคนยากจนหรือไม่?           th
#
#                              poll_category_name
# 0                                  Comunicación
# 6                                     Inclusión
# 57                                   Protección
# 67                    Participación Adolescente
# 96                                    Educación
# 118                                       Salud
# 150                          Fechas Importantes
# 313                          Igualdad de Género
# 352                            Cambio Climático
# 978                                Adolescencia
# 1001                              Participación
# 1026                                      Niñez
# 1042                                   embarazo
# 1099                                    General
# 1113                                 Ureporteri
# 1209                            U-Report Brasil
# 1233                                      Saúde
# 1307                                   Educação
# 1353                          ODS 2 - Fome Zero
# 1393                                         +Q
# 1397   Objetivos do Desenvolvimento Sustentável
# 1404                                        ODS
# 1452                              Mete a colher
# 1461                                  ODS Geral
# 1491                                       HIV
# 1503                                   Política
# 1509                                  Migrantes
# 1561                                   Aprendiz
# 1638                                   Esportes
# 1650                           Violência Sexual
# ...                                         ...
# 39223              SDGs - Цілі сталого розвитку
# 39267                                 LifeStyle
# 39271                                  Здоров'я
# 39319                                  Загальні
# 39447                              Саморозвиток
# 39606        #EndViolence - Протидія насильству
# 39620                               Урбаністика
# 39709                          U-Report у світі
# 39751                                 Мистецтво
# 40934                         Гендерна рівність
# 41039                                  New Year
# 41073                                  ВІЛ/СНІД
# 41867                                 Education
# 41872                     Corona Virus Response
# 41910                              Child Rights
# 41918                             Mental Health
# 41920                                Well Being
# 41930                                      Poll
# 41944                 Violence Against Children
# 41956                               เสียงเยาวชน
# 41983                           การคุ้มครองเด็ก
# 42034                                  การศึกษา
# 42154                                     อื่นๆ
# 42268                 นโยบายสังคม และ งานรณรงค์
# 42348                             เอชไอวี/เอดส์
# 42397                              Other images
# 42548                                    สุขภาพ
# 42572                                 สิทธิเด็ก
# 43915                          สถานการณ์ฉุกเฉิน
# 44480                            ความเหลื่อมล้ำ
#
# [316 rows x 4 columns]

# %%
translate_to_eng('Comunicación', 'es')
# Out:
# it worked
# 'Comunicación'

# %%
_only_uniq_categs['poll_category_translation'] = _only_uniq_categs.progress_apply(lambda x: translate_to_eng(x.poll_category_name, x.org_language),
                                                       axis=1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 316/316 [03:05<00:00,  1.71it/s]
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
_only_uniq_categs
# Out:
#                                               poll_title  \
# 0      ¿Cuáles son las redes sociales preferidas por ...
# 6      ¿Cómo afecta el Aislamiento Preventivo Social ...
# 57     ¿Cómo es la situación en el hogar de los adole...
# 67     Covid-19: ¿Qué acciones pueden tomar los adole...
# 96         Educación a Distancia en contexto de Covid-19
# 118        Actitudes y comportamientos sobre el COVID-19
# 150                        Día Internacional de la Mujer
# 313      #DíaDeLaNiña ¿Cuál es el trabajo de tus sueños?
# 352                                     Cambio Climático
# 978    COVID 19 - Actitudes y comportamientos durante...
# 1001                    Rumbo a la pacificación del país
# 1026   La Convención sobre los derechos del niño y la...
# 1042   Un 14% de los nacimientos en Bolivia es de mad...
# 1099                              COVID 19 i obrazovanje
# 1113                          Anketa o PISA istraživanju
# 1209         Uso da internet durante o isolamento social
# 1233   Adolescentes e jovens diante da pandemia de co...
# 1307   Acesso ao ensino superior | Pesquisadores Soci...
# 1353                                 Nutrição 2 | UNICEF
# 1393                                 Voluntariado UNICEF
# 1397   Cidades Amigas das Crianças | Child Friendly C...
# 1404                            Contra violência online!
# 1452      Uma colherada na relação abusiva e violências!
# 1461                   Amém Axé | Intolerância Religiosa
# 1491                                      Combate ao HIV
# 1503                Quem decide o que se fala na escola?
# 1509                           Refugiados y migrantes II
# 1561   U-Report pergunta: E a Lei da Aprendizagem, ju...
# 1638               Direito ao Esporte Seguro e Inclusivo
# 1650                                          MandaNude!
# ...                                                  ...
# 39223                                         Енергетика
# 39267                              Святкування Великодня
# 39271                                Молодь на карантині
# 39319                        Відчуття безпеки (повторне)
# 39447                            Молодіжні події (Луцьк)
# 39606                                 Домашнє насильство
# 39620                  Відїзд молоді з міста (Маріуполь)
# 39709  Вплив молоді у місті (Засідання мерів щодо діт...
# 39751                           Центри культурних послуг
# 40934   Виклики для дівчат і жінок (сільська місцевість)
# 41039                               Новорічне опитування
# 41073                            День боротьби зі СНІДом
# 41867                    Impact of COVID-19 on Education
# 41872  COVID-19 Risk Perception at Community Level Su...
# 41910                                                CRC
# 41918               World Mental Health Day - 10 October
# 41920                            الصحة النفسية والرفاهية
# 41930                         مستقبل - Youth Aspirations
# 41944                             Ending Violence Online
# 41956  เราได้ร่วมมือกับองค์การแรงงานระหว่างประเทศ (IL...
# 41983  เรามีโพลสำรวจใหม่มาฝากให้วัยรุ่นช่วยแสดงความคิ...
# 42034  เรายังคงสำรวจความคิดเห็นของวัยรุ่นเกี่ยวกับเรื...
# 42154                               Dare to Dream Poll 1
# 42268  เราอยากรู้ว่าวัยรุ่นไทยสนใจงานด้านอาสาสมัครมาก...
# 42348  เราได้ร่วมมือกับมูลนิธิ Path2Health เพื่อสำรวจ...
# 42397  เราได้จับมือกับสำนักงานกองทุนสนับสนุนการสร้างเ...
# 42548  ทุกปียูนิเซฟจะจัดทำรายงานสภาวะเด็กโลก ซึ่งสำรว...
# 42572  เราได้ร่วมมือกับกลุ่มการศึกษาเพื่อความเป็นไทอี...
# 43915  ภัยพิบัติต่างๆ สร้างความสูญเสียแก่ชุมชนและครอบ...
# 44480  เด็กที่อยู่ในครอบครัวยากจน จะขาดโอกาสในหลายๆ ด...
#
#                                           question_title org_language  \
# 0                   ¿Cuál es la red social que más usás?           es
# 6      Mencione los tres cambios más importantes en l...           es
# 57     Durante la cuarentena, ¿quién hace la mayor pa...           es
# 67                 ¿Qué tipo de acciones querés conocer?           es
# 96     Para quienes se encuentran estudiando actualme...           es
# 118       ¿Cómo te has sentido estos últimos siete días?           es
# 150    ¿Considerás que las mujeres deberían tener igu...           es
# 313                   ¿Cuál es el trabajo de tus sueños?           es
# 352    ¿Considerás que a través de tus acciones podés...           es
# 978    ¿Qué opción describe mejor cómo te has sentido...           es
# 1001   ¿Qué te causó más molestia o preocupación dura...           es
# 1026      ¿Sabes a quién protegen los derechos del niño?           es
# 1042         ¿Conoces casos de adolescentes embarazadas?           es
# 1099   Koliko vremena dnevno provodiš prateći i radeć...           bs
# 1113               Da li si čuo-la za PISA istraživanje?           bs
# 1209          De qual forma você mais acessa a internet?        pt-br
# 1233                           Você mora em uma capital?        pt-br
# 1307                              Quantos anos você tem?        pt-br
# 1353   Quais são os tipos de alimentos ofertados na m...        pt-br
# 1393   Você está interessado em trabalhar como volunt...        pt-br
# 1397   Os políticos da sua cidade escutam a opinião d...        pt-br
# 1404                 Is there a helpline in your country        pt-br
# 1452   Meninos | Você sente que possui espaços seguro...        pt-br
# 1461        Já ouviu falar sobre intolerância religiosa?        pt-br
# 1491   Você sabe onde pode realizar o exame gratuitam...        pt-br
# 1503   Você acha que a escola é um espaço importante ...        pt-br
# 1509   Q8 would you advise your family members or fri...        pt-br
# 1561   Você acha importante ter uma lei que garanta o...        pt-br
# 1638   A escola possui equipamentos para prática espo...        pt-br
# 1650   Você conhece alguém que tenha tido fotos íntim...        pt-br
# ...                                                  ...          ...
# 39223  Чи знаєте Ви, з яких джерел виробляється елект...           uk
# 39267                 Як Ви плануєте провести Великдень?           uk
# 39271  Наскільки комфортно психологічно Вам знаходити...           uk
# 39319  Яке ваше внутрішнє сприйняття рівня безпеки в ...           uk
# 39447  Як часто Ви відвідуєте невеликі (до 50 людей) ...           uk
# 39606  Чи стикалися Ви з домашнім насильством щодо Ва...           uk
# 39620  Чи маєте Ви намір покинути місто на тривалий час?           uk
# 39709  На Вашу думку, якими були б найефективніші мех...           uk
# 39751  Як часто Ви відвідуєте заклади культури (біблі...           uk
# 40934  У яких сферах є найбільші виклики для дівчат і...           uk
# 41039                        Де Ви зустрічали Новий рік?           uk
# 41073  Чи хочете Ви взяти участь в опитуванні до Всес...           uk
# 41867  ?Were you at school before the current movemen...           ar
# 41872                        ?Have you heard of COVID-19           ar
# 41910         كم دولة صدقت على اتفاقية حقوق الطفل (CRC)؟           ar
# 41918  برأيك، ما هي الأسباب التي تمنع الأشخاص من الحص...           ar
# 41920  هل تعتقد أنه يجب بذل المزيد من الجهد لتعليم وت...           ar
# 41930  مرحبًا، نود أن نعرف ما هى الأفكار التي تدور في...           ar
# 41944  هل كانت الحالة: \r\r\nنشر على العلن عبر الانتر...           ar
# 41956  น้องๆ คิดว่าประเทศไทยต้องการแรงงานข้ามชาติหรือ...           th
# 41983                              Are u ready to answer           th
# 42034  ตอนนี้น้องๆ มีความมั่นใจไหมคะว่าจะสามารถมีชีวิ...           th
# 42154  น้องๆ คิดว่าตัวน้องเองต้องเร่งพัฒนาความสามารถด...           th
# 42268             น้อง ๆ ชอบทำกิจกรรมอาสาสมัครกันไหมครับ           th
# 42348                    น้องๆ เคยขอถุงยางอนามัยฟรีไหมคะ           th
# 42397             ปกติน้องๆ เล่นเกมออนไลน์บ่อยแค่ไหนครับ           th
# 42548  น้องๆ คิดว่าปกติตัวเองกินอาหารอย่างระวังสุขภาพ...           th
# 42572  สิทธิขั้นพื้นฐานในสถานศึกษาด้านไหนที่น้องอยากไ...           th
# 43915  น้องๆ คิดว่าตนเองมีความรู้เรื่องการเตรียมความพ...           th
# 44480  น้องๆ คิดว่า ในชุมชนที่น้องอยู่ มีคนยากจนหรือไม่?           th
#
#                              poll_category_name  \
# 0                                  Comunicación
# 6                                     Inclusión
# 57                                   Protección
# 67                    Participación Adolescente
# 96                                    Educación
# 118                                       Salud
# 150                          Fechas Importantes
# 313                          Igualdad de Género
# 352                            Cambio Climático
# 978                                Adolescencia
# 1001                              Participación
# 1026                                      Niñez
# 1042                                   embarazo
# 1099                                    General
# 1113                                 Ureporteri
# 1209                            U-Report Brasil
# 1233                                      Saúde
# 1307                                   Educação
# 1353                          ODS 2 - Fome Zero
# 1393                                         +Q
# 1397   Objetivos do Desenvolvimento Sustentável
# 1404                                        ODS
# 1452                              Mete a colher
# 1461                                  ODS Geral
# 1491                                       HIV
# 1503                                   Política
# 1509                                  Migrantes
# 1561                                   Aprendiz
# 1638                                   Esportes
# 1650                           Violência Sexual
# ...                                         ...
# 39223              SDGs - Цілі сталого розвитку
# 39267                                 LifeStyle
# 39271                                  Здоров'я
# 39319                                  Загальні
# 39447                              Саморозвиток
# 39606        #EndViolence - Протидія насильству
# 39620                               Урбаністика
# 39709                          U-Report у світі
# 39751                                 Мистецтво
# 40934                         Гендерна рівність
# 41039                                  New Year
# 41073                                  ВІЛ/СНІД
# 41867                                 Education
# 41872                     Corona Virus Response
# 41910                              Child Rights
# 41918                             Mental Health
# 41920                                Well Being
# 41930                                      Poll
# 41944                 Violence Against Children
# 41956                               เสียงเยาวชน
# 41983                           การคุ้มครองเด็ก
# 42034                                  การศึกษา
# 42154                                     อื่นๆ
# 42268                 นโยบายสังคม และ งานรณรงค์
# 42348                             เอชไอวี/เอดส์
# 42397                              Other images
# 42548                                    สุขภาพ
# 42572                                 สิทธิเด็ก
# 43915                          สถานการณ์ฉุกเฉิน
# 44480                            ความเหลื่อมล้ำ
#
#                       poll_category_translation
# 0                                  Comunicación
# 6                                     Inclusión
# 57                                   Protección
# 67                    Participación Adolescente
# 96                                    Educación
# 118                                       Salud
# 150                          Fechas Importantes
# 313                          Igualdad de Género
# 352                            Cambio Climático
# 978                                Adolescencia
# 1001                              Participación
# 1026                                      Niñez
# 1042                                   embarazo
# 1099                                    General
# 1113                                 Ureporteri
# 1209                            U-Report Brasil
# 1233                                      Saúde
# 1307                                   Educação
# 1353                          ODS 2 - Fome Zero
# 1393                                         +Q
# 1397   Objetivos do Desenvolvimento Sustentável
# 1404                                        ODS
# 1452                              Mete a colher
# 1461                                  ODS Geral
# 1491                                       HIV
# 1503                                   Política
# 1509                                  Migrantes
# 1561                                   Aprendiz
# 1638                                   Esportes
# 1650                           Violência Sexual
# ...                                         ...
# 39223              SDGs - Цілі сталого розвитку
# 39267                                 LifeStyle
# 39271                                  Здоров'я
# 39319                                  Загальні
# 39447                              Саморозвиток
# 39606        #EndViolence - Протидія насильству
# 39620                               Урбаністика
# 39709                          U-Report у світі
# 39751                                 Мистецтво
# 40934                         Гендерна рівність
# 41039                                  New Year
# 41073                                  ВІЛ/СНІД
# 41867                                 Education
# 41872                     Corona Virus Response
# 41910                              Child Rights
# 41918                             Mental Health
# 41920                                Well Being
# 41930                                      Poll
# 41944                 Violence Against Children
# 41956                               เสียงเยาวชน
# 41983                           การคุ้มครองเด็ก
# 42034                                  การศึกษา
# 42154                                     อื่นๆ
# 42268                 นโยบายสังคม และ งานรณรงค์
# 42348                             เอชไอวี/เอดส์
# 42397                              Other images
# 42548                                    สุขภาพ
# 42572                                 สิทธิเด็ก
# 43915                          สถานการณ์ฉุกเฉิน
# 44480                            ความเหลื่อมล้ำ
#
# [316 rows x 5 columns]

# %%
translate

# %%
non_eng_polls.iloc[1208]
# Out:
# poll_title                         BreastMilk and No water Campaign
# question_title    (For YES answers): Ok, What else should be giv...
# org_language                                                     fr
# Name: 2998, dtype: object

# %%
non_eng_polls['poll_category_translation'] = non_eng_polls.progress_apply(lambda x: translate_to_eng(x.poll_category_name, x.org_language),
                                                       axis=1)
# Out:
#   2%|█▋                                                                          | 592/26776 [03:04<2:15:38,  3.22it/s]
#
# KeyboardInterrupt

# %% [markdown]
# More Efficient Approach- do not translate every line.
# Instead, replace with a dictionary of all unique values and translate back.

# %%
categ_map = {}
for category in all_poll_categs:
    categ_map['category'] = translate_unknown_to_eng(category)

# %%
poll_categories = non_eng_polls['poll_category_translation'].unique()

# %%
#What would be interesting is to see the differences to the same poll questions across different segments
non_eng_polls['poll_translation'] = non_eng_polls.progress_apply(lambda x: translate_to_eng(x.poll_title, x.org_language),
                                                       axis=1)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10780/10780 [47:11<00:00,  3.81it/s]

# %%
poll_topics = non_eng_polls['poll_translation'].unique()

# %%
print(len(poll_topics))
# Out:
# 3126

# %%
print(poll_topics)
# Out:
# ['What are the preferred social networks for Argentine teens?'
#  '¿Cuáles son las redes sociales preferidas por los adolescentes argentinos?'
#  'How does Social and Mandatory Preventive Isolation affect households with Disabilities?'
#  ...
#  'The Convention on the Rights of the Child states that the children have the right to express themselves in their thoughts. And their opinions should be considered as appropriate\r\n\r\nWhat level of opinion do you think you can exercise your rights to participate in?'
#  "Don't know friends Of U-readers have experienced cyberbullying? And do you know what if bullying is seen online?"
#  'Thailand signed as a member of the Convention on the Rights of the Child on 12 February 1992. Did you know that this Convention? What are the key principles in protecting the basic rights of children?']

# %%
poll_categories.to_pickle('../non_english_category_titles.pkl')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-eac163c44fdf> in <module>()
# ----> 1 poll_categories.to_pickle('../non_english_category_titles.pkl')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_pickle'

# %%
#Save this for later use
poll_topics.to_pickle('../non_english_poll_titles.pkl')
# Merge with the English poll titles

# %% [markdown]
# The questions need to be organized by some measure of similarity. There are many different ways of doing this but we will start with the overview covered in this comprehensive medium post:
# https://medium.com/@adriensieg/text-similarities-da019229c894
# and the associated github repository:
# https://github.com/adsieg/text_similarity/blob/master/Different%20Embeddings%20%2B%20Cosine%20Similarity%20%2B%20HeatMap%20illustration.ipynb

# %%
import spacy
nlp = spacy.load("en_core_web_md")
tokens = nlp("dog cat banana afskfsd")

# %%
from googletrans import Translator
translator = Translator()

# %%
translator.translate('bonjour', src='fr').text
# Out:
# 'bonjour'

# %%
for token1 in tokens:
    for token2 in tokens:
        print(token1.text, token2.text, token1.similarity(token2))
# Out:
# dog dog 1.0
# dog cat 0.80168545
# dog banana 0.24327648
# dog afskfsd 0.0
# cat dog 0.80168545
# cat cat 1.0
# cat banana 0.28154367
# cat afskfsd 0.0
# banana dog 0.24327648
# banana cat 0.28154367
# banana banana 1.0
# banana afskfsd 0.0
# afskfsd dog 0.0
# afskfsd cat 0.0
# afskfsd banana 0.0
# afskfsd afskfsd 1.0
# C:\Users\HP\Anaconda3\lib\runpy.py:193: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   "__main__", mod_spec)
# C:\Users\HP\Anaconda3\lib\runpy.py:193: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   "__main__", mod_spec)
# C:\Users\HP\Anaconda3\lib\runpy.py:193: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   "__main__", mod_spec)
# C:\Users\HP\Anaconda3\lib\runpy.py:193: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   "__main__", mod_spec)
# C:\Users\HP\Anaconda3\lib\runpy.py:193: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   "__main__", mod_spec)
# C:\Users\HP\Anaconda3\lib\runpy.py:193: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   "__main__", mod_spec)

# %%
gloveFile = "data\\glove.6B.50d.txt"
import numpy as np
def loadGloveModel(gloveFile):
    print ("Loading Glove Model")
    with open(gloveFile, encoding="utf8" ) as f:
        content = f.readlines()
    model = {}
    for line in content:
        splitLine = line.split()
        word = splitLine[0]
        embedding = np.array([float(val) for val in splitLine[1:]])
        model[word] = embedding
    print ("Done.",len(model)," words loaded!")
    return model

def preprocess(raw_text):

    # keep only words
    letters_only_text = re.sub("[^a-zA-Z]", " ", raw_text)

    # convert to lower case and split 
    words = letters_only_text.lower().split()

    # remove stopwords
    stopword_set = set(stopwords.words("english"))
    cleaned_words = list(set([w for w in words if w not in stopword_set]))

    return cleaned_words

def cosine_distance_between_two_words(word1, word2):
    import scipy
    return (1- scipy.spatial.distance.cosine(model[word1], model[word2]))

def calculate_heat_matrix_for_two_sentences(s1,s2):
    s1 = preprocess(s1)
    s2 = preprocess(s2)
    result_list = [[cosine_distance_between_two_words(word1, word2) for word2 in s2] for word1 in s1]
    result_df = pd.DataFrame(result_list)
    result_df.columns = s2
    result_df.index = s1
    return result_df

def cosine_distance_wordembedding_method(s1, s2):
    import scipy
    vector_1 = np.mean([model[word] for word in preprocess(s1)],axis=0)
    vector_2 = np.mean([model[word] for word in preprocess(s2)],axis=0)
    cosine = scipy.spatial.distance.cosine(vector_1, vector_2)
    print('Word Embedding method with a cosine distance asses that our two sentences are similar to',round((1-cosine)*100,2),'%')

def heat_map_matrix_between_two_sentences(s1,s2):
    df = calculate_heat_matrix_for_two_sentences(s1,s2)
    import seaborn as sns
    import matplotlib.pyplot as plt
    fig, ax = plt.subplots(figsize=(5,5)) 
    ax_blue = sns.heatmap(df, cmap="YlGnBu")
    # ax_red = sns.heatmap(df)
    print(cosine_distance_wordembedding_method(s1, s2))
    return ax_blue

# %%
len(df[df['org_language']=="es"]['question_title'].unique())

# %%
# We don't know yet what each of these language odes means

# %%
#https://stackoverflow.com/questions/27842613/pandas-groupby-sort-within-groups

# %%
# What would be useful is to find the polls that ask the same question in multiple languages
# Then we could check for differences

# %%
wide_df = df.pivot()
