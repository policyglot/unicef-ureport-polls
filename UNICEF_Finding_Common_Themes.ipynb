# %% [markdown]
# # UNICEF- Finding Common Themes

# %% [markdown]
# This notebook serves to convert the original dataset into clusters of translated questions with similar themes

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# Requirement already satisfied: googletrans==4.0.0-rc1 in c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: sniffio in c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.2.0)
# Requirement already satisfied: idna==2.* in c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: chardet==3.* in c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: httpcore==0.9.* in c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: hstspreload in c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2020.11.21)
# Requirement already satisfied: certifi in c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2020.6.20)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.4.0)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: sniffio in c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.2.0)
# Requirement already satisfied: h2==3.* in c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)

# %%
pd.options.mode.chained_assignment = None

# %%
#First,the usual imports
import numpy as np
import pandas as pd
import random
from tqdm import tqdm
tqdm.pandas()
import re
from nltk.corpus import stopwords
# Out:
# c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages\tqdm\std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
#Now the aim is to translate all the questions and find the relevant ones
from googletrans import Translator
translator = Translator()

# %%
df = pd.read_csv('ureport_sample.csv')

# %%
non_eng_polls = df[df['org_language'] != 'en'][['poll_title', 'question_title', 
                                                'org_language', 'poll_category_name']]
#It would make sense to remove duplicates

# %%
all_poll_categs = non_eng_polls['poll_category_name'].unique()
print(len(all_poll_categs))
print(all_poll_categs)
# Out:
# 299
# ['Comunicación' 'Inclusión' 'Protección' 'Participación Adolescente'
#  'Educación' 'Salud' 'Fechas Importantes' 'Igualdad de Género'
#  'Cambio Climático' 'Adolescencia' 'Participación' 'Niñez' 'embarazo'
#  'General' 'Ureporteri' 'U-Report Brasil' 'Saúde' 'Educação'
#  'ODS 2 - Fome Zero' '+Q' 'Objetivos do Desenvolvimento Sustentável' 'ODS'
#  'Mete a colher' 'ODS Geral' 'HIV ' 'Política' 'Migrantes' 'Aprendiz'
#  'Esportes' 'Violência Sexual' 'Evasão Escolar' 'Corpo e Gordofobia'
#  'ODS 5 - Igualdade de Gênero' 'Corpo' 'Redução' 'Juv e Trabalho'
#  'Direitos Reprodutivos e Prevenções' 'Proteção'
#  "ODS 14 - Vida debaixo D'Água"
#  'ODS 9 - Indústria, Inovação e Infraestrutura'
#  'ODS 3 - Saúde e Bem-Estar' 'ODS 1 - Erradicação da Pobreza'
#  'Abordagem Policial' 'Acesso à justiça' 'ARMAS' 'DROGAS' 'Rede LGBT'
#  'Letalidade Violenta' 'Segurança' 'S4D' 'Opinions' 'Participation'
#  'Education' 'Santé' 'Cybercrime' 'Nutrition' 'Hygiène'
#  "Droits de l'enfant" 'Général' 'Eau, Assainissement et Hygiène'
#  "Protection de l'enfant" 'Environnement' 'Helpline' 'Sustentabilidad'
#  'Contingencia' 'Politique Social' 'Jeunesse' 'Jeunessse  / Adolescence'
#  'Enfance' 'U-Report' 'Opiniones' 'Participation des jeunes' 'Protection '
#  'Eau et hygiène' 'VIH/Sida' "Droits de l'Homme" 'Emploi' 'Média'
#  'Diplomatie' 'Consommation' 'Politique' 'Sports' 'Économie et finances'
#  'Innovations' 'Santé reproductive sexuelle' 'Culture' 'Emergencia'
#  'Emergencias' 'Políticas Sociales' 'Zika' 'Internet' 'Éducation'
#  'Citoyenneté' 'Protection' 'Engagement/solidarité' 'Sport' 'Inégalités'
#  "Radio Mouv'" 'Agua y sanimiento' 'Salud Adolescente' 'Protección '
#  'U-Report Guatemala' 'Participación adolescente' 'Uso de tiempo libre'
#  'Cambio Climático 2' 'Primera Infancia' 'Matrimonio infantil'
#  'Embarazo adolescente' 'Objetivos de Desarrollo Sostenible (ODS)'
#  'SANTÉ ' 'GOUVERNANCE' 'POLITIQUES SOCIALES (Social inclusion)'
#  'EDUCATION' 'Wash' 'SPORT' 'VIH/ SIDA' "PROTECTION DE L'ENFANT"
#  'Communcation Externe' 'Droits des enfants' 'Niñez y adolescencia'
#  'Join & Engage' 'Redes sociales' 'Políticas' 'Innovation' 'ADAP'
#  'Child Protection' 'Social Policy' 'HIV/AIDS' 'Immunization'
#  'Children on the Move' 'Derechos' 'Tecnología' 'Alte sondaje'
#  'Sănătate și bunăstare' 'Media și tehnologie' 'Educație și viața școlară'
#  'Drepturile copiilor & monitorizare' 'Carieră'
#  'Monitorizarea drepturilor' 'Obiectivele de Dezvoltare Durabilă'
#  'Participare si dezvoltare' 'Protecția copilului' 'Mediu înconjurător'
#  'CORONAVIRUS 2019 - (COVID-19)' 'EMPREGO' 'Ouro Negro'
#  'Inquérito de Satisfação sobre Serviços de SSR - 09 Dec 2019'
#  'Child Protection - Bilhete de Identidade' 'Ciclone IDAI e Cheias'
#  'Campanha de Vacinacao do Polio' 'Social Mobilizers_WASH Interventions'
#  'CIDADES AMIGAS DAS CRIANCAS' 'Saúde Materna Infantil'
#  'Pré-Campanha sobre a Pólio - 28 a 29 de Janeiro 2018'
#  'São Valentim - Dia dos Namorados'
#  'Inquérito de Satisfação sobre Serviços de SSR - SOFH 15.12.18'
#  'World Children Day 20th November 2018' 'Radionovela os Intxunáveis'
#  'Prevencao do consumo de alcool, tabaco e drogas  ilegais.'
#  'Inquérito Global sobre os Cuidados de Saúde Primários'
#  'Violencia nas escolas' 'Dia Internacional do Albinismo'
#  'DIA MUNDIAL DA CRIANÇA' 'DIA INTERNACIONAL DA MULHER'
#  'HIV, TRANSMISSÃO, PREVENÇÃO, TRATAMENTO' 'ADESÃO AS UNIDADES SANITÁRIAS'
#  'SMS BIZ - COMO USAR' 'Higiene Menstrual - 28 Maio'
#  'SAÚDE SEXUAL E REPRODUTIVA' 'EDUCAÇÃO' 'Violência contra as Raparigas'
#  'Casamentos Prematuros' 'Violência contra Menores' 'Comunicação'
#  'MALARIA' 'RELACIONAMENTOS' 'SEXUALIDADE' 'Health' 'Climate Change'
#  'Governance' 'Youth & Digital' 'Youth' 'Disaster' 'Infrastructure'
#  'Child protection' 'Peace and Social Cohesion' 'Gender' 'Employment'
#  'Youth policy' 'U-reporters General' 'Outbreaks' 'Water and Sanitation'
#  'Advocacy 4' 'Ureport & Policy Makers ' 'GIRL CHILD ' 'SDGs'
#  'Innovation ' "Partner's poll" 'OVP polls' 'Global poll' 'Polio comms'
#  'FMoH/NPHCDA' 'COVID19' 'Diritti' 'Emergenza' 'Coinvolgimento giovani'
#  'Hate speech' 'Aspirazioni' 'Scuola' 'Accesso ai servizi' 'Tolleranza'
#  'Orientamento Professionale' 'Sistema di accoglienza'
#  'Informazioni legali' 'Attività ricreative' 'Ambiente' 'Sondaje' 'Paix'
#  'Santé- Wash' 'Santé et Nutrition' 'U-Report Senegal'
#  'Plaidoyer et Participation' 'VIH/SIDA' 'Emploi et Entrepreneuriat '
#  'Zaštita životne sredine' 'Obrazovanje' 'Ankete' 'Bezbednost'
#  'Obrada podataka' 'Prioriteti mladih' 'Ishrana' 'Zapošljavanje'
#  'Informisanje' 'Ravnopravnost' 'Prevencija nasilja' 'Communication'
#  'Sante' 'Hygiene' 'Entreprenariat' 'Changement Climatique' 'Polio'
#  'Volontariat en Tunisie' "Lutte contre l'abandon scolaire"
#  'Journée mondiale des enfants'
#  "Journée mondiale des enfants (World Children's Day)"
#  "Violence à l'égard des enfants et adolescents" 'Migration'
#  'Citoyenneté mondiale' 'Transport scolaire' 'Sujets U-Report'
#  "Ta'lim / Образование" 'Jamiyat / Общество'
#  "Sog'liqni saqlash / Здравоохранение" 'Ish / Работа'
#  'Innovatsiya / Инновация' 'Yoshlar / Молодежь' "Bo'sh vaqt / Досуг"
#  'Ijtimoiy masalalar / Социальные вопросы' 'Cyber Bullying'
#  'Bạo lực công cộng' 'Bạo lực gia đình' 'School bullying'
#  'U-Report Albania - Local Polls' 'Kosovo Local Polls'
#  'Montenegro Local Polls' 'U-Report Western Balkans' 'Youth Engagement'
#  'WASH' 'Climate and Environment' 'Освіта' 'SDGs - Цілі сталого розвитку'
#  'LifeStyle' "Здоров'я" 'Загальні' 'Саморозвиток'
#  '#EndViolence - Протидія насильству' 'Урбаністика' 'U-Report у світі'
#  'Мистецтво' 'Гендерна рівність' 'New Year' 'ВІЛ/СНІД'
#  'Corona Virus Response' 'Child Rights' 'Mental Health' 'Well Being'
#  'Poll' 'Violence Against Children' 'เสียงเยาวชน' 'การคุ้มครองเด็ก'
#  'การศึกษา' 'อื่นๆ' 'นโยบายสังคม และ งานรณรงค์' 'เอชไอวี/เอดส์'
#  'Other images' 'สุขภาพ' 'สิทธิเด็ก' 'สถานการณ์ฉุกเฉิน' 'ความเหลื่อมล้ำ']

# %% [markdown]
# Important Observations:
# - Some of these themes are in two languages separated by a slash.
# - Some polls- especially in the Balkan region- simply use 'Polls' or 'U-Report' in the titles. We will have to dig deeper to find the questions within them
#
# There are only 299 categories. We will now create a function to store a dictionary of these 299 mappings (and any changes resulting from the points above). This would prove more efficient than running Google Translate over thousands of lines of code. It would most likely push us past the daily API call limit.

# %% [markdown]
# ## Preprocessing for Google Translate

# %%
#We are assuming that the language codes are the same in Google Translate and our data
non_eng_polls['org_language'].unique()
# Out:
# array(['es', 'bs', 'pt-br', 'bg', 'fr', 'id', 'ar', 'ro', 'pt', 'my', nan,
#        'it', 'sr-rs@latin', 'uz', 'vi', 'uk', 'th'], dtype=object)

# %% [markdown]
# Cross-checking against the Google Translate list, we find a few mismatches
# https://cloud.google.com/translate/docs/languages

# %%
non_eng_polls.loc[non_eng_polls['org_language']=='sr-rs@latin']
# Out:
#             poll_title                                     question_title  \
# 22126  Životna sredina  Da li si informisan/a o stanju životne sredine...
# 22127  Životna sredina  Da li si informisan/a o stanju životne sredine...
# 22128  Životna sredina  Da li si informisan/a o stanju životne sredine...
# 22129  Životna sredina  Da li si informisan/a o stanju životne sredine...
# 22130  Životna sredina  Da li si informisan/a o stanju životne sredine...
# ...                ...                                                ...
# 23221          Nasilje  Kom tipu nasilja nad decom bi najpre trebalo d...
# 23222          Nasilje  Na koji način bi deca trebalo da se uključe ka...
# 23223          Nasilje  Na koji način bi deca trebalo da se uključe ka...
# 23224          Nasilje  Na koji način bi deca trebalo da se uključe ka...
# 23225          Nasilje  Na koji način bi deca trebalo da se uključe ka...
#
#       org_language       poll_category_name
# 22126  sr-rs@latin  Zaštita životne sredine
# 22127  sr-rs@latin  Zaštita životne sredine
# 22128  sr-rs@latin  Zaštita životne sredine
# 22129  sr-rs@latin  Zaštita životne sredine
# 22130  sr-rs@latin  Zaštita životne sredine
# ...            ...                      ...
# 23221  sr-rs@latin       Prevencija nasilja
# 23222  sr-rs@latin       Prevencija nasilja
# 23223  sr-rs@latin       Prevencija nasilja
# 23224  sr-rs@latin       Prevencija nasilja
# 23225  sr-rs@latin       Prevencija nasilja
#
# [1100 rows x 4 columns]

# %% [markdown]
# A quick check reveals that this is Serbian/Croatian, which is represented in Google translate as 'hr'.
# Brazilian Portuguese can be replaced by Portuguese.

# %%
#Completing the first two replacements
non_eng_polls['org_language'].replace('pt-br', 'pt', inplace=True)
non_eng_polls['org_language'].replace('sr-rs@latin', 'hr', inplace=True)

# %%
#Exploring the Uzbek case
non_eng_polls.loc[non_eng_polls['org_language']=='uz']
# Out:
#                                               poll_title  \
# 37217  Karantinda bolalar vaqtini uyda qanday o’tkazy...
# 37218  Karantinda bolalar vaqtini uyda qanday o’tkazy...
# 37219  Karantinda bolalar vaqtini uyda qanday o’tkazy...
# 37220  Karantinda bolalar vaqtini uyda qanday o’tkazy...
# 37221  Karantinda bolalar vaqtini uyda qanday o’tkazy...
# ...                                                  ...
# 38166  Yoshlarning ijtimoiy faolligi / Социальная акт...
# 38167  Yoshlarning ijtimoiy faolligi / Социальная акт...
# 38168  Yoshlarning ijtimoiy faolligi / Социальная акт...
# 38169  Yoshlarning ijtimoiy faolligi / Социальная акт...
# 38170  U-Reportda nima haqida muloqot qilmoqchisiz? /...
#
#                                           question_title org_language  \
# 37217  2)\tSiz bu bolaga kimsiz? / Кем Вы являетесь д...           uz
# 37218  3)\tKarantin tufayli bog'chalar yopilganidan s...           uz
# 37219  6)\tBog’chaga borolmaslik, do’stlari, tarbiyac...           uz
# 37220  6)\tBog’chaga borolmaslik, do’stlari, tarbiyac...           uz
# 37221  6)\tBog’chaga borolmaslik, do’stlari, tarbiyac...           uz
# ...                                                  ...          ...
# 38166  Tuman/mahallangizni o’zgartirish bo’yicha g’oy...           uz
# 38167  Tuman/mahallangizni o’zgartirish bo’yicha g’oy...           uz
# 38168  Tuman/mahallangizni o’zgartirish bo’yicha g’oy...           uz
# 38169  Tuman/mahallangizni rivojlantirishda ko’ngilli...           uz
# 38170  U-Reportda qaysi mavzularda muloqot qilisni is...           uz
#
#          poll_category_name
# 37217  Ta'lim / Образование
# 37218  Ta'lim / Образование
# 37219  Ta'lim / Образование
# 37220  Ta'lim / Образование
# 37221  Ta'lim / Образование
# ...                     ...
# 38166    Yoshlar / Молодежь
# 38167    Yoshlar / Молодежь
# 38168    Yoshlar / Молодежь
# 38169    Yoshlar / Молодежь
# 38170    Yoshlar / Молодежь
#
# [954 rows x 4 columns]

# %% [markdown]
# Fortunately, because of its Soviet history, the Uzbek questions carries the Russian translation after a slash. This could come in handy in case the lookup in Uzbek fails. Currently however, it may be a liability by including two languages in one piece of text. So we will remove the Russian that occurs after the slash.

# %%
def keep_preslash(text):
    return text.split('/')[0]

# %%
print(keep_preslash('Yoshlar / Молодежь'))
# Out:
# Yoshlar

# %%
non_eng_polls.loc['poll_category_name'] = non_eng_polls['poll_category_name'].apply(lambda x: keep_preslash(x.poll_category_name) if x.org_language=='uz' else x.poll_category_name,
                                                                                    axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-eb02e6723c43> in <module>
# ----> 1 non_eng_polls.loc['poll_category_name'] = non_eng_polls['poll_category_name'].apply(lambda x: keep_preslash(x.poll_category_name) if x.org_language=='uz' else x.poll_category_name,
#       2                                                                                     axis=1)
#
# c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4211             else:
#    4212                 values = self.astype(object)._values
# -> 4213                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4214
#    4215         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# c:\users\hp\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\series.py in f(x)
#    4196
#    4197             def f(x):
# -> 4198                 return func(x, *args, **kwds)
#    4199
#    4200         else:
#
# TypeError: <lambda>() got an unexpected keyword argument 'axis'

# %%
non_eng_polls.loc[non_eng_polls['org_language']=='uz']['poll_category_name']
# Out:
# 37217    Ta'lim / Образование
# 37218    Ta'lim / Образование
# 37219    Ta'lim / Образование
# 37220    Ta'lim / Образование
# 37221    Ta'lim / Образование
#                  ...
# 38166      Yoshlar / Молодежь
# 38167      Yoshlar / Молодежь
# 38168      Yoshlar / Молодежь
# 38169      Yoshlar / Молодежь
# 38170      Yoshlar / Молодежь
# Name: poll_category_name, Length: 954, dtype: object

# %% [markdown]
# ## Translation Function

# %%
import time

# %%
def translate_to_eng(txt, src_lang):
    """
    takes in text in a non-english language
    returns the english translation
    """
    
    try:
        print('it worked')
        result = translator.translate(txt, 
                     src=src_lang, dest="en")
    #In case the organization's language label doesn't match the question language
    except:
        result = translator.translate(txt, dest="en")
        
    return result.text

# %%
def translate_unknown_to_eng(txt):
    """
    takes in text in a non-english language (not specified by user)
    returns the english translation
    """
    
    try:
        result = translator.translate(txt,
                                    dest="en")
        return result.text
    #In case the organization's language label doesn't match the question language
    except:
        return txt

# %%
#Testing the function
print(translate_unknown_to_eng('Prevencija nasilja'))
# Out:
# Prevention of violence

# %%
print(translate_to_eng('Prevencija nasilja', 'hr'))
# Out:
# it worked
# Prevention of violence

# %%
time.sleep(10)
print(translate_to_eng('Bonjour', 'fr'))
# Out:
# it worked
# Hello

# %%
unique_non_eng_polls = non_eng_polls.drop_duplicates(subset=['poll_category_name'])

# %%
unique_non_eng_polls
# Out:
#                                               poll_title  \
# 0      ¿Cuáles son las redes sociales preferidas por ...
# 6      ¿Cómo afecta el Aislamiento Preventivo Social ...
# 57     ¿Cómo es la situación en el hogar de los adole...
# 67     Covid-19: ¿Qué acciones pueden tomar los adole...
# 96         Educación a Distancia en contexto de Covid-19
# ...                                                  ...
# 42397  เราได้จับมือกับสำนักงานกองทุนสนับสนุนการสร้างเ...
# 42548  ทุกปียูนิเซฟจะจัดทำรายงานสภาวะเด็กโลก ซึ่งสำรว...
# 42572  เราได้ร่วมมือกับกลุ่มการศึกษาเพื่อความเป็นไทอี...
# 43915  ภัยพิบัติต่างๆ สร้างความสูญเสียแก่ชุมชนและครอบ...
# 44480  เด็กที่อยู่ในครอบครัวยากจน จะขาดโอกาสในหลายๆ ด...
#
#                                           question_title org_language  \
# 0                   ¿Cuál es la red social que más usás?           es
# 6      Mencione los tres cambios más importantes en l...           es
# 57     Durante la cuarentena, ¿quién hace la mayor pa...           es
# 67                 ¿Qué tipo de acciones querés conocer?           es
# 96     Para quienes se encuentran estudiando actualme...           es
# ...                                                  ...          ...
# 42397             ปกติน้องๆ เล่นเกมออนไลน์บ่อยแค่ไหนครับ           th
# 42548  น้องๆ คิดว่าปกติตัวเองกินอาหารอย่างระวังสุขภาพ...           th
# 42572  สิทธิขั้นพื้นฐานในสถานศึกษาด้านไหนที่น้องอยากไ...           th
# 43915  น้องๆ คิดว่าตนเองมีความรู้เรื่องการเตรียมความพ...           th
# 44480  น้องๆ คิดว่า ในชุมชนที่น้องอยู่ มีคนยากจนหรือไม่?           th
#
#               poll_category_name
# 0                   Comunicación
# 6                      Inclusión
# 57                    Protección
# 67     Participación Adolescente
# 96                     Educación
# ...                          ...
# 42397               Other images
# 42548                     สุขภาพ
# 42572                  สิทธิเด็ก
# 43915           สถานการณ์ฉุกเฉิน
# 44480             ความเหลื่อมล้ำ
#
# [299 rows x 4 columns]

# %%
unique_non_eng_polls['poll_category_eng'] = unique_non_eng_polls['poll_category_name'].progress_apply(translate_unknown_to_eng)
# Out:
#   0%|                                                                                          | 0/299 [00:00<?, ?it/s]
#   1%|▌                                                                                 | 2/299 [00:00<00:33,  8.94it/s]
#   1%|▊                                                                                 | 3/299 [00:00<00:40,  7.39it/s]
#   1%|█                                                                                 | 4/299 [00:00<00:50,  5.84it/s]
#   2%|█▎                                                                                | 5/299 [00:00<00:52,  5.62it/s]
#   2%|█▋                                                                                | 6/299 [00:01<00:54,  5.35it/s]
#   2%|█▉                                                                                | 7/299 [00:01<01:00,  4.84it/s]
#   3%|██▏                                                                               | 8/299 [00:01<00:59,  4.87it/s]
#   3%|██▍                                                                               | 9/299 [00:01<00:55,  5.24it/s]
#   3%|██▋                                                                              | 10/299 [00:01<00:57,  5.06it/s]
#   4%|██▉                                                                              | 11/299 [00:02<00:53,  5.41it/s]
#   4%|███▎                                                                             | 12/299 [00:02<00:51,  5.61it/s]
#   4%|███▌                                                                             | 13/299 [00:02<00:57,  4.93it/s]
#   5%|███▊                                                                             | 14/299 [00:02<00:55,  5.13it/s]
#   5%|████                                                                             | 15/299 [00:02<00:55,  5.10it/s]
/s]
#  96%|████████████████████████████████████████████████████████████████████████████▊   | 287/299 [00:59<00:02,  4.68it/s]
#  96%|█████████████████████████████████████████████████████████████████████████████   | 288/299 [01:00<00:02,  4.15it/s]
#  97%|█████████████████████████████████████████████████████████████████████████████▎  | 289/299 [01:00<00:02,  4.73it/s]
#  97%|█████████████████████████████████████████████████████████████████████████████▌  | 290/299 [01:00<00:01,  4.88it/s]
#  97%|█████████████████████████████████████████████████████████████████████████████▊  | 291/299 [01:00<00:01,  4.99it/s]
#  98%|██████████████████████████████████████████████████████████████████████████████▏ | 292/299 [01:00<00:01,  5.31it/s]
#  98%|██████████████████████████████████████████████████████████████████████████████▍ | 293/299 [01:00<00:01,  5.54it/s]
#  98%|██████████████████████████████████████████████████████████████████████████████▋ | 294/299 [01:01<00:00,  5.60it/s]
#  99%|██████████████████████████████████████████████████████████████████████████████▉ | 295/299 [01:01<00:00,  4.72it/s]
#  99%|███████████████████████████████████████████████████████████████████████████████▏| 296/299 [01:01<00:00,  4.67it/s]
#  99%|███████████████████████████████████████████████████████████████████████████████▍| 297/299 [01:01<00:00,  4.64it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████▋| 298/299 [01:02<00:00,  4.34it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 299/299 [01:02<00:00,  4.78it/s]
# <ipython-input-30-e3ab247db721>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_non_eng_polls['poll_category_eng'] = unique_non_eng_polls['poll_category_name'].progress_apply(translate_unknown_to_eng)

# %%
unique_non_eng_polls.sort_values(by='poll_category_eng')
# Out:
#                                               poll_title  \
# 39606                                 Домашнє насильство
# 1393                                 Voluntariado UNICEF
# 8480     Poll: Apakah citra diri memengaruhi perilakumu?
# 1906        Acesso à justiça: para todos ou para alguns?
# 19706       Conoscenza e servizi sulla violenza sessuale
# ...                                                  ...
# 5338                      Día Mundial contra el Mosquito
# 42548  ทุกปียูนิเซฟจะจัดทำรายงานสภาวะเด็กโลก ซึ่งสำรว...
# 20511   Sondaj despre Obiectivele de Dezvoltare Durabilă
# 1042   Un 14% de los nacimientos en Bolivia es de mad...
# 1638               Direito ao Esporte Seguro e Inclusivo
#
#                                           question_title org_language  \
# 39606  Чи стикалися Ви з домашнім насильством щодо Ва...           uk
# 1393   Você está interessado em trabalhar como volunt...           pt
# 8480   Seberapa puas atau tidak puaskah kamu terhadap...           id
# 1906   Se a escola violar seus direitos, você acessar...           pt
# 19706                    Sono...Maschio, Femmina o Altro           it
# ...                                                  ...          ...
# 5338   1. ¿A cuántas personas mata el mosquito/zancud...           es
# 42548  น้องๆ คิดว่าปกติตัวเองกินอาหารอย่างระวังสุขภาพ...           th
# 20511  Ai auzit până acum despre Obiectivele de Dezvo...           ro
# 1042         ¿Conoces casos de adolescentes embarazadas?           es
# 1638   A escola possui equipamentos para prática espo...           pt
#
#                        poll_category_name                   poll_category_eng
# 39606  #EndViolence - Протидія насильству  #EndViolence - Countering violence
# 1393                                   +Q                                  +Q
# 8480                                 ADAP                                ADAP
# 1906                     Acesso à justiça                   Access to justice
# 19706                  Accesso ai servizi                  Access to services
# ...                                   ...                                 ...
# 5338                                 Zika                                Zika
# 42548                              สุขภาพ                              health
# 20511                             Sondaje                               polls
# 1042                             embarazo                           pregnancy
# 1638                             Esportes                              sports
#
# [299 rows x 5 columns]

# %% [markdown]
# This sorting behaviour seems odd. Not clear why health, polls, and sports are at the bottom, after Z (Zika)

# %%
sorted(unique_non_eng_polls['poll_category_eng'].unique())
# Out:
# ['#EndViolence - Countering violence',
#  '+Q',
#  'ADAP',
#  'Access to justice',
#  'Access to services',
#  'Adolescence',
#  'Adolescent Health',
#  'Adolescent Participation',
#  'Adolescent participation',
#  'Advocacy 4',
#  'Advocacy and Participation',
#  'Apprentice',
#  'Art',
#  'Aspirations',
#  'Average',
#  'Black Gold',
#  'Body',
#  'Body and Gordophobia',
#  'CHILD FRIENDLY CITIES',
#  'CHILD PROTECTION',
#  'CORONAVIRUS 2019 - (COVID-19)',
#  'COVID19',
#  'Career',
#  'Cheers',
#  'Child Protection',
#  'Child Protection - Identity Card',
#  'Child Rights',
#  'Child marriage',
#  'Child protection',
#  'Childhood',
#  'Childhood and adolescence',
#  'Children on the Move',
#  "Children's rights",
#  "Children's rights & monitoring",
#  'Citizenship',
#  'Climate Change',
#  'Climate Change 2',
#  'Climate and Environment',
#  'Climate change',
#  'Commitment / solidarity',
#  'Common',
#  'Communication',
#  'Communication Externe',
#  'Consumption',
#  'Contingency',
#  'Corona Virus Response',
#  'Culture',
#  'Cyber Bullying',
#  'Cybercrime',
#  'Cyclone IDAI and Floods',
#  'Data processing',
#  'Diplomacy',
#  'Disaster',
#  'Domestic violence',
#  'Drugs',
#  'EDUCATION',
#  'Early childhood',
#  'Economy and finance',
#  'Education',
#  'Education and school life',
#  'Emergencies',
#  'Emergency',
#  'Emergency situation',
#  'Employment',
#  'Employment and Entrepreneurship',
#  'Entrepreneurship',
#  'Environment',
#  'Environmental protection',
#  'Equality',
#  'Famah / Nafkada',
#  'Feedback',
#  'Fight against dropping out of school',
#  'GIRL CHILD',
#  'GOVERNANCE',
#  'Gender',
#  'Gender equality',
#  'General',
#  'Global Survey on Primary Health Care',
#  'Global citizenship',
#  'Global poll',
#  'Governance',
#  'HEALTH',
#  'HIV',
#  'HIV / AIDS',
#  'HIV, TRANSMISSION, PREVENTION, TREATMENT',
#  'Hate speech',
#  'Health',
#  'Health / Zdravooxranenie',
#  'Health and Nutrition',
#  'Health and well-being',
#  'Health- Wash',
#  'Helpline',
#  'Human rights',
#  'Hygiene',
#  "INTERNATIONAL WOMEN'S DAY",
#  'Ijtimoiy masalalar / Social issues',
#  'Immunization',
#  'Important dates',
#  'Inclusion',
#  'Inequality',
#  'Informing',
#  'Infrastructure',
#  'Innovation',
#  'Innovations',
#  'International Albinism Day',
#  'Internet',
#  'Ish / Work',
#  'JOB',
#  'Jamiyat / Society',
#  'Join & Engage',
#  'Juv and Work',
#  'Kosovo Local Polls',
#  'LGBT Network',
#  'Legal information',
#  'Leisure / Friend',
#  'LifeStyle',
#  'MALARIA',
#  'MEMBERSHIP TO SANITARY UNITS',
#  'Maternal Child Health',
#  'Media and technology',
#  'Menstrual Hygiene - 28 May',
#  'Mental Health',
#  'Migrants',
#  'Migration',
#  'Montenegro Local Polls',
#  'New Year',
#  'Nutrition',
#  'ODS',
#  'ODS 2 - Fome Zero',
#  'ODS Geral',
#  'OVP polls',
#  'Opinions',
#  'Other',
#  'Other images',
#  'Other polls',
#  'Outbreaks',
#  'Participation',
#  'Participation and development',
#  "Partner's poll",
#  'Peace',
#  'Peace and Social Cohesion',
#  'Police approach',
#  'Policies',
#  'Polio',
#  'Polio Pre-Campaign - January 28-29, 2018',
#  'Polio Vaccination Campaign',
#  'Polio comms',
#  'Politics',
#  'Poll',
#  'Polls',
#  'Premature Weddings',
#  'Prevention of alcohol, tobacco and illegal drugs consumption.',
#  'Prevention of violence',
#  'Professional orientation',
#  'Protection',
#  'Public violence',
#  'Put the spoon',
#  'RELATIONSHIPS',
#  "Radio Mov '",
#  'Radionovela the Intxunáveis',
#  'Reception system',
#  'Recreational activities',
#  'Recruitment',
#  'Reduction',
#  'Reproductive Rights and Prevention',
#  'Rights',
#  'Rights monitoring',
#  'Rights of the child',
#  'S4D',
#  'SDG 1 - Poverty Eradication',
#  'SDG 14 - Life Under Water',
#  'SDG 3 - Health and Well-Being',
#  'SDG 5 - Gender Equality',
#  'SDG 9 - Industry, Innovation and Infrastructure',
#  'SDGs',
#  'SDGs - Sustainable Development Goals',
#  'SEXUAL AND REPRODUCTIVE HEALTH',
#  'SEXUALITY',
#  'SMS BIZ - HOW TO USE',
#  'SOCIAL POLICIES (Social inclusion)',
#  'SPORT',
#  'SSR Services Satisfaction Survey - 09 Dec 2019',
#  'SSR Services Satisfaction Survey - SOFH 15.12.18',
#  'Safety',
#  'Sante',
#  'School',
#  'School Dropout',
#  'School bullying',
#  'School transportation',
#  'Security',
#  'Self development',
#  'Sexual Violence',
#  'Sexual reproductive health',
#  'Social Mobilizers_WASH Interventions',
#  'Social Policy',
#  'Social Policy and Campaign',
#  'Social networks',
#  'Social policy',
#  'Social politics',
#  'Sport',
#  'Sports',
#  'Sustainability',
#  'Sustainable Development Goals',
#  'Sustainable Development Goals (SDG)',
#  "Ta'lim / Education",
#  'Technology',
#  'Teenage pregnancy',
#  'Tolerance',
#  'U-Report',
#  'U-Report Albania - Local Polls',
#  'U-Report Brasil',
#  'U-Report Guatemala',
#  'U-Report Senegal',
#  'U-Report Topics',
#  'U-Report Western Balkans',
#  'U-Report in the world',
#  'U-reporters General',
#  'Urbanism',
#  'Ureport & Policy Makers',
#  'Ureporteri',
#  'Use of free time',
#  'VIH / PAGE',
#  'VIH / Sida',
#  "Valentine's Day - Valentine's Day",
#  'Violence Against Children',
#  'Violence against Girls',
#  'Violence against Minors',
#  'Violence against children and adolescents',
#  'Violence in schools',
#  'Violent lethality',
#  'Volunteering in Tunisia',
#  'WASH',
#  'WEAPONS',
#  "WORLD CHILD'S DAY",
#  'Wash',
#  'Water and Sanitation',
#  'Water and hygiene',
#  'Water and sanitation',
#  'Water, Sanitation and Hygiene',
#  'Well Being',
#  'World Children Day 20th November 2018',
#  "World Children's Day",
#  "World children's day",
#  'Youth',
#  'Youth & Digital',
#  'Youth / Adolescence',
#  'Youth / Youth',
#  'Youth Engagement',
#  'Youth involvement',
#  'Youth participation',
#  'Youth policy',
#  'Youth priorities',
#  'Youth voice',
#  'Zika',
#  'health',
#  'polls',
#  'pregnancy',
#  'sports']

# %% [markdown]
# From this initial look, it seems like we have a few themes that are showing up across countries.
# - We might need to remove the upper case letters in some cses
# - The Uzbek terms, as expected, had two languages in the original title. So only the Russian has been translated
# - Some polls are simply titled 'Polls'. We will need a separate sub-category for them
